# %% [markdown]
# *TITANIC ANALYSIS INDEX*
# ===
#
# - [0.History](#0.History)
# - [1.Column Description](#1.Column-Description)
# - [2.Encoding](#2.Encoding)
#     - [2.1 Sex](#2.1-Sex)
#     - [2.2 Embarked](#2.2-Sex)
# - [3.Correlations](#3.Correlations)
#     - [3.1 Pearson](#3.1-Pearson)
#     - [3.2 Kendall](#3.2-Kendall)
#     - [3.3 Spearman](#3.3-Spearman)
#     - [3.4 Detailed Correlation](#3.4-Detailed-Correlation)

# %% [markdown]
# 0.History
# ===

# %% [markdown]
# But by far the largest group of passengers was in Third Class: more than 700, exceeding the other two levels combined. Some had paid less than 20 to make the crossing.
#
# In compliance with the law of the sea, women and children boarded the boats first.Yet many of the victims were in fact women and children.
#
# Gaining a bit more understanding of the problem context can provide several clues about the importance of variables, and help us make more sense of some of the relations that will be uncovered during our exploratory data analysis. So it's worth spending some time learning about what happened the night the Titanic sank (we can think of this as gaining some domain expertise). There are countless books, documentaries, and webpages dedicated to this subject. Here we highlight a few interesting facts:
#
# <ul>
#     <li>The Titanic's officers issued a "women and children first" order for evacuating passengers via lifeboats. However, there was no organized evacuation plan in place.</li>
#     <li>There was in fact no general "abandon ship" order given by the captain, no public address system, and no lifeboat drill. Many passengers did not realize they were in any imminent danger, and some had to be goaded out of their cabins by members of the crew or staff.</li>
#     <li>Lifeboats were segregated into different class sections, and there were more 1st-class passenger lifeboats than for the other two classes.</li>
#     <li>We know it was more difficult for 3rd class passengers to access lifeboats, because the 3rd-class passenger sections were gated off from the 1st and 2nd-class areas of the ship. This was actually due to US immigration laws, which required immigrants (primarily 3rd-class) to be segregated and processed separately from other passengers upon arrival to the US. As a consequence, 3rd-class passengers had to navigate through a maze of staircases and corridors to reach the lifeboat deck.</li>
# </ul>
# Given these facts, we can already surmize that Sex, Pclass, and Age are likely to be the most important features. We will see what trends our Exploratory Data Analysis reveals.
#
# Conerning the Fare feature: Fare is given in Pounds Sterling. There were really no 'standard' fares - many factors influenced the price charged, including the cabin size and number of people sharing a cabin, whether it was on the perimeter of the ship (i.e. with a porthole) or further inside, the qualities of the furnishings and provisions, etc. Children travelled at reduced rates, as did servants with 1st-class tickets. There seemed also to have been some family discount rates given, but we lack detailed information on how this was calculated. However, our research does tell us that:
#
# Ticket price (Fare) was cumulative, and included the cost for all passengers sharing that ticket.

# %% [markdown]
# A Quick Glance at the Sorted CSV File
# Several useful observations can be made by quickly glancing at the CSV file containing the combined training and test data, and sorting some of the entries. Don't underestimate the usefulness of this rather rudimentary step!
#
# Findings:
#
# <ul>
#     <li>Sort by Passenger Name: Passengers with matching surnames tend to also have matching entries for several other features: Pclass, Ticket, Fare, and Embarked (in addition to Cabin when available). This tells us we can use matching Ticket and Fare information as a basis for grouping families. If we sort by ticket, we can use surnames to distinguish between 'family' groups and non-related co-travellers. </li>
#     <li>Sort by Age: All entries with the title 'Master' in the name correspond to males under the age of 15. This can be useful in helping us impute missing age data.</li>
#     <li>Sort by Cabin: We find that Cabin number is available for most passengers with PClass=1, but generally missing for passengers of Pclass=2 or 3.</li>
#     <li>Sort by Ticket Names: (I.Tickets not containing letters.) Tickets with 4-digits correspond to Pclass 2 or 3; the vast majority of 5-digit tickets correspond to Pclass 1 or 2; for 6-digit and 7-digit tickets, the leading number matches the Pclass. (II. Tickets including letters.) Tickets beginning with A/4 correspond to passengers with embarked=S and PClass=3. Tickets beginning with C.A. or CA also correspond to embarked=S, with PClass of 2 or 3. All tickets beginning with PC correspond to PClass=1. These patterns might be useful for helping us spot inconsistencies in the data.</li>
# </ul>

# %% [markdown]
# 1.Column Description
# ===

# %% [markdown]
# <ul>
#     <li><b>pclass</b>: A proxy for socio-economic status (SES)</li>
#         <ul>
#           <li>1st = Upper</li>
#           <li>2nd = Middle</li>
#           <li>3rd = Lower</li>
#         </ul>
#     <li><b>age</b>: Age is fractional if less than 1. If the age is estimated, it is in the form of xx.5</li>
#     <li><b>sibsp</b>: is the number of siblings or spouse of a person onboard. A maximum of 8 siblings and spouses traveled along with one of the traveler.</li>
#     <li><b>parch</b>: Similar to the SibSp, this feature contained the number of parents or children each passenger was touring with.</li>
#     <li><b>ticket</b>:	Ticket number	</li>
#     <li><b>fare</b>:	Passenger fare o tariffa</li>
#     <li><b>cabin</b>:	Cabin number	</li>
#     <li><b>embarked</b>:	Port of Embarkation. Embarked implies where the traveler mounted from. There are three possible values for Embark — Southampton, Cherbourg, and Queenstown</li>
# </ul>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import math
import warnings
#import plotly.express as px

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve
#from xgboost import XGBClassifier
import warnings

#import plotly.express as px
#from plotly.subplots import make_subplots
#import plotly.figure_factory as ff
#import plotly.offline as offline
#import plotly.graph_objs as go

test = pd.read_csv("./test.csv")
train = pd.read_csv("./train.csv")
df_data = pd.concat([train, test], sort=True).reset_index(drop=True)
df_data_train = train.copy()
df_data_1 =df_data.copy()

# %%
df_data.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1046 non-null   float64
#  1   Cabin        295 non-null    object
#  2   Embarked     1307 non-null   object
#  3   Fare         1308 non-null   float64
#  4   Name         1309 non-null   object
#  5   Parch        1309 non-null   int64
#  6   PassengerId  1309 non-null   int64
#  7   Pclass       1309 non-null   int64
#  8   Sex          1309 non-null   object
#  9   SibSp        1309 non-null   int64
#  10  Survived     891 non-null    float64
#  11  Ticket       1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
df_data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2.Encoding
# ===

# %% [markdown]
# Since the string data does not go well with the machine learning algorithms, I needed to convert the non-numeric data to numeric data. I used LabelEncoder to encode the ‘Sex’ column. The label encoder would substitute ‘male’ values with some number and ‘female’ values with some different number.
# td['Sex'] = LabelEncoder().fit_transform(td['Sex'])
# For the other categorical data, I used Pandas’ dummies. It adds columns corresponding to all the possible values. So, if there could be three embarkment values — Q, C, S, the get_dummies method would create three different columns and assign values 0 or 1 depending on the embarking point.

# %% [markdown]
# 2.1 Sex
# ---

# %% [markdown]
# Utilizziamo come convenzione male = 0 e female = 1

# %%
df_data_1['Sex'] = df_data_1['Sex'].replace(['male'], '0')
df_data_1['Sex'] = df_data_1['Sex'].replace(['female'], '1')
df_data_1['Sex'] = df_data_1['Sex'].astype("int64")
df_data_train['Sex'] = df_data_train['Sex'].replace(['male'], '0')
df_data_train['Sex'] = df_data_train['Sex'].replace(['female'], '1')
df_data_train['Sex'] = df_data_train['Sex'].astype("int64")

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1046 non-null   float64
#  1   Cabin        295 non-null    object
#  2   Embarked     1307 non-null   object
#  3   Fare         1308 non-null   float64
#  4   Name         1309 non-null   object
#  5   Parch        1309 non-null   int64
#  6   PassengerId  1309 non-null   int64
#  7   Pclass       1309 non-null   int64
#  8   Sex          1309 non-null   int64
#  9   SibSp        1309 non-null   int64
#  10  Survived     891 non-null    float64
#  11  Ticket       1309 non-null   object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 122.8+ KB

# %%
df_data_1.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass  Sex  SibSp  Survived            Ticket
# 0       3    0      1       0.0         A/5 21171
# 1       1    1      1       1.0          PC 17599
# 2       3    1      0       1.0  STON/O2. 3101282
# 3       1    1      1       1.0            113803
# 4       3    0      0       0.0            373450

# %% [markdown]
# 2.2 Embarked
# ---

# %%
df_data_1['Embarked'] = df_data_1['Embarked'].replace(['C'], '0')
df_data_1['Embarked'] = df_data_1['Embarked'].replace(['Q'], '1')
df_data_1['Embarked'] = df_data_1['Embarked'].replace(['S'], '2')
#Devo usare il float perchè la conversione da float NaN a int dà errore
df_data_1['Embarked'] = df_data_1['Embarked'].astype("float64")
df_data_train['Embarked'] = df_data_train['Embarked'].replace(['C'], '0')
df_data_train['Embarked'] = df_data_train['Embarked'].replace(['Q'], '1')
df_data_train['Embarked'] = df_data_train['Embarked'].replace(['S'], '2')
#Devo usare il float perchè la conversione da float NaN a int dà errore
df_data_train['Embarked'] = df_data_train['Embarked'].astype("float64")

# %%
df_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1046 non-null   float64
#  1   Cabin        295 non-null    object
#  2   Embarked     1307 non-null   float64
#  3   Fare         1308 non-null   float64
#  4   Name         1309 non-null   object
#  5   Parch        1309 non-null   int64
#  6   PassengerId  1309 non-null   int64
#  7   Pclass       1309 non-null   int64
#  8   Sex          1309 non-null   int64
#  9   SibSp        1309 non-null   int64
#  10  Survived     891 non-null    float64
#  11  Ticket       1309 non-null   object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 122.8+ KB

# %% [markdown]
# 3.Correlations
# ===

# %% [markdown]
# 3.1 Pearson
# ---

# %% [markdown]
# La correlazione di Pearson è utilizzabile con due assunzioni:
# <ul>
#    <li>la distribuzione dei dati è gaussiana</li>
#     <li>la rappresentazione cartesiana è <b>lineare</b></li>
# </ul>
# Quindi il primo punto debole di questa correlazione è che un legame non lineare viene interpretato come correlazione 0!
# E' il tipo di correlazione più semplice e basato sulla relazione:

# %% [markdown]
# ![PearsonCorr.jpg](attachment:PearsonCorr.jpg)

# %% [markdown]
# Dalla matrice di correlazione costruita si notano le seguenti dipendenze in ordine d'importanza:
# <ul>
#     <li> PClass e Fare : 0.56</li>
#     <li> Sex e Survived : 0.54</li>
#     <li> PClass e Age : 0.41</li>
#     <li> PClass e Survived : 0.34</li>
#     <li> Parch e SibSp : 0.37</li>
# </ul>

# %%
df_heatmap = pd.DataFrame(df_data_1.corr(method='pearson').abs())
f,ax = plt.subplots(figsize=(10,5),facecolor='white')
sns.color_palette("rocket", as_cmap=True)  
sns.heatmap(df_heatmap,annot = True,square=True, linewidths=1.5, cmap='rocket')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3.2 Kendall
# ---

# %% [markdown]
# La correlazione di Kendall invece segue un approccio diverso
#
# <ol>
#   <li>Ranking: si ordinano i dati secondo la variabile indipendente</li>
#   <li>Primo Compare: si confronta la prima variabile indipendente in cima alla tabella ordinata con tutti gli altri sample indipendenti x<sub>i+1</sub> > x<sub>i</sub> </li>
#   <li>Secondo Compare: si confronta la prima variabile dipendente associata alla prima variabile indip. con la successiva variabile dipendente verificando se y<sub>i+1</sub> > y<sub>i</sub> </li>
#   <li>Concorde o Discorde: se x<sub>i+1</sub> > x<sub>i</sub> e y<sub>i+1</sub> > y<sub>i</sub> sono entrambe vere si incrementa un valore <b>Nc</b> (numero di check concordi)   altrimenti s'incrementa <b>Nd</b> (numero di check discordi) </li>
#   <li>Si eseguono i passi 2 e 3 scorrendo la tabella verso il basso, fissando ogni volta una coppia di variabili dip. e indip. e confrontandole con tutte le altre</li>
# </ol>
#
# Questo tipo di correlazione è perciò un po' più grossolana perchè non dà una percezione profonda della curva che stiamo analizzando ma il vantaggio è che la relazione potrebbe anche essere<b> non lineare</b>

# %% [markdown]
# ![KendalCorr.png](attachment:KendalCorr.png)

# %% [markdown]
# Dalla matrice di correlazione costruita si notano le seguenti dipendenze in ordine d'importanza:
# <ul>
#     <li> PClass e Fare : 0.85</li>
#     <li> PClass e Survived : 0.71</li>
#     <li> Age e Parch : 0.68</li>
#     <li> Age e PClass : 0.61</li>
#     <li> Age e SibSp : 0.57</li>
#     <li> Age e Survived : 0.55</li>
# </ul>

# %%
df_heatmap = pd.DataFrame(df_data_1.corr(method='kendall').abs())
f,ax = plt.subplots(figsize=(10,5),facecolor='white')
sns.color_palette("rocket", as_cmap=True)  
sns.heatmap(df_heatmap,annot = True,square=True, linewidths=1.5, cmap='rocket')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3.3 Spearman
# ---

# %% [markdown]
# La correlazione di Spearman è simile a quella di Pearson con la differenza che il sample da confrontare viene ordinato. Successivamente si calcola la distanza tra due set di campioni per mezzo di una semplice differenza portata poi al quadrato. La correlazione di Spearman è molto più sensibile alle variazioni dei dati rispetto alla correlazione di Kendall. Sotto un esempio:

# %% [markdown]
# ![SpearmanCorr.png](attachment:SpearmanCorr.png)

# %% [markdown]
# ![SpearmanCorr2.PNG](attachment:SpearmanCorr2.PNG)

# %% [markdown]
# Dalla matrice di correlazione costruita si notano le seguenti dipendenze in ordine d'importanza:
# <ul>
#     <li> PClass e Fare : 0.71</li>
#     <li> PClass e Fare : 0.54</li>
#     <li> SibSp e Fare : 0.45</li>
#     <li> SibSp e Parch : 0.44</li>
#     <li> Age e PClass : 0.4</li>
#
# </ul>

# %%
df_heatmap = pd.DataFrame(df_data_1.corr(method='spearman').abs())
f,ax = plt.subplots(figsize=(10,5),facecolor='white')
sns.color_palette("rocket", as_cmap=True)  
sns.heatmap(df_heatmap,annot = True,square=True, linewidths=1.5, cmap='rocket')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4.Data imputation
# ===

# %% [markdown]
# Innanzi tutto verifico se ci sono dei campi vuoti nella tabella

# %%
cols_with_missing = [col for col in df_data_1.columns if df_data_1[col].isnull().any()] 
pd.isnull(df_data_1[cols_with_missing]).sum()
# Out:
# Age          263
# Cabin       1014
# Embarked       2
# Fare           1
# Survived     418
# dtype: int64

# %% [markdown]
# E' necessario sostituire i campi vuoti con dei valori che abbiano un senso logico.

# %% [markdown]
# 4.1 Age Missing Values
# ---

# %% [markdown]
# E' interessante verificare come è distrubita l'età in funzione delle classi. Per fare questo usiamo dei grafici molto interessanti, chiamati <b>violin plot</b> perchè somigliano nella forma proprio a dei violini.
# Questi grafici sono molto interessanti perchè racchiudono parecchie informazioni:
# <ul>
#     <li><b>Distribuzione</b>:queste forme non vi ricordano qualcosa? Ma guarda un po' delle <b>gaussiane</b> o anche denominate curve a campana! Bisogna farci un po' l'occhio perchè le curve vengono specchiate (non so per quale motivo perchè basterebbe guardarne metà)</li>
#     <li><b>Media</b>:a occhio possiamo già vedere che per le Classi meno abbienti 2 e 3, la media d'età è piuttosto bassa che può essere ragionevole</li>
#     <li><b>Deviazione standard</b> : anche questo parametro importantissimo si nota ad occhio quanto sia differente nelle tre curve. Nella Classe 1 la deviazione è più ampia cioè l'intervallo d'età è più distribuito. Nelle Classi 2 e 3 invece la deviazione è più ridotta quindi il range d'età è più ridotto </li>
# </ul>

# %%
sns.violinplot(x='Pclass', y="Age", data=df_data_1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# Per farvi render conto di quanto sia importante rappresentare nel modo più sintetico i dati vi mostro un altro modo per visualizzare i dati di Age e Pclass:

# %%
dimensions = (10, 6)
fig, ax = plt.subplots(figsize=dimensions)
sns.histplot(ax = ax, data=df_data_1, x="Age" , hue="Pclass",multiple="stack")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# Anche qui si possono fare delle considerazioni ma risultano un po' più sparse. Chiaro il discorso? In questa rappresentazione si vede meglio quale sia la proporzione tra le classi

# %% [markdown]
# To address the problem of missing values for the **<span style='color:#F1C40F'>Age</span>** field we will proceed as follows. Since **<span style='color:#F1C40F'>PClass</span>** is the variable that is **<span style='color:#F1C40F'>most correlated</span>** with both Age and Survived, we will group passengers according to the class they belong to. What we will do is replace the missing values with the **<span style='color:#F1C40F'>median</span>** of each group. In fact, what is more, within each of the existing classes we will make a **<span style='color:#F1C40F'>gender distinction</span>**. We do this because, as we will see below, the median of Age varies according to whether the passenger is male or female.

# %%
sr_mediana = df_data_1.groupby(['Sex', 'Pclass']).median()['Age']
sr_mediana
#for i in range(0,sr_mediana.shape[0]):
#    if i<3: 
#        print('Median age for female of class {}: {}'.format(i+1,sr_mediana[1][i+1]))
#    else:
#        print('Median age for male of class {}: {}'.format(i+1-3,sr_mediana[0][i+1-3]))
df_data_1.Age = df_data_1.groupby(['Sex', 'Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))
#print('Missing values for Age: {}'.format(df_data.Age.isnull().sum()))

# %% [markdown]
# 4.2 Embarked Missing Values
# ---

# %% [markdown]
# Negli imbarcati 2 solo campi sono vuoti. Sostituiamo i vuoti con il valore più frequente, ossia la moda. In questo caso la moda è 2.

# %%
df_data_1.Embarked.value_counts()
# Out:
# 2.0    914
# 0.0    270
# 1.0    123
# Name: Embarked, dtype: int64

# %%
df_data_1.Embarked.fillna(df_data_1.Embarked.mode()[0], inplace = True)
pd.isnull(df_data_1).sum()
# Out:
# Age               0
# Cabin          1014
# Embarked          0
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
df_data_1.shape[1]
# Out:
# 22

# %% [markdown]
# 4 Univariate Feature Exploration
# ===

# %%
def barplots(dataframe, features, cols=2, width=10, height=10, hspace=0.5, wspace=0.25):
    # define style and layout
    sns.set(font_scale=1.5)
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width, height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataframe.shape[1]) / cols)
    # define subplots
    for i, column in enumerate(dataframe[features].columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        sns.barplot(column,'Survived', data=dataframe)
        plt.xticks(rotation=0)
        plt.xlabel(column, weight='bold')

    
feature_list = ['Sex','Pclass', 'Embarked', 'SibSp', 'Parch', 'FamilySize']        
barplots(df_data_1, features=feature_list, cols=3, width=15, height=40, hspace=0.35, wspace=0.4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8228/2062091538.py in <module>
#      15
#      16 feature_list = ['Sex','Pclass', 'Embarked', 'SibSp', 'Parch', 'FamilySize']
# ---> 17 barplots(df_data_1, features=feature_list, cols=3, width=15, height=40, hspace=0.35, wspace=0.4)
#
# ~\AppData\Local\Temp/ipykernel_8228/2062091538.py in barplots(dataframe, features, cols, width, height, hspace, wspace)
#       7     rows = math.ceil(float(dataframe.shape[1]) / cols)
#       8     # define subplots
# ----> 9     for i, column in enumerate(dataframe[features].columns):
#      10         ax = fig.add_subplot(rows, cols, i + 1)
#      11         sns.barplot(column,'Survived', data=dataframe)
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['SibSp', 'Parch'] not in index"

# %% [markdown]
# 4.3 Class, Age and Sex
# ---

# %% [markdown]
# Per capire i dati che seguono è utile capire un po' di più sullo scopo del Titanic. Su Wikipedia viene mostrato il percorso che avrebbe dovuto fare il transatlantico: partenza Southampton, raccolta passeggeri a Cherbourg e Queenstown e destinazione New York. In quale posto migliore si poteva approdare per trovare un posto di lavoro  in America?
#
# Per questo il transatlantico era per la maggior parte composto da immigranti in cerca di fortuna. E' molto probabile quindi che gli immigranti fossero intere famiglie.

# %% [markdown]
# ![Titanic_voyage_map.png](attachment:Titanic_voyage_map.png)

# %% [markdown]
# Vediamo il numero di passeggeri suddiviso per classe ..

# %%
sr_Age_Pclass1 = (df_data_1['Pclass']==1).sum()
sr_Age_Pclass2 = (df_data_1['Pclass']==2).sum()
sr_Age_Pclass3 = (df_data_1['Pclass']==3).sum()

# %%
d_Age_Pclass = {'Passengers per Pclass':[sr_Age_Pclass1, sr_Age_Pclass2, sr_Age_Pclass3] }
sr_Age_Pclass = pd.DataFrame(data=d_Age_Pclass , index=[1, 2, 3])  
sr_Age_Pclass
# Out:
#    Passengers per Pclass
# 1                    323
# 2                    277
# 3                    709

# %% [markdown]
# .. e diviso per sesso, poi li raggruppiamo..

# %%
sr_Sex_Pclass1 = df_data_1.groupby('Sex')['Pclass'].apply(lambda x: x[x ==1].count()) 
sr_Sex_Pclass2 = df_data_1.groupby('Sex')['Pclass'].apply(lambda x: x[x ==2].count()) 
sr_Sex_Pclass3 = df_data_1.groupby('Sex')['Pclass'].apply(lambda x: x[x ==3].count()) 
sr_Sex_Pclass1
# Out:
# Sex
# 0    179
# 1    144
# Name: Pclass, dtype: int64

# %% [markdown]
# Ora creiamo una tabella riassuntiva per capire la percentuale di passeggeri suddivisa per sesso e classe e la combiniamo con la rappresentazione della funzione di distribuzione dell'età per ciascuna delle categorie (2 sessi x 3 classi).
#
# Rappresentare la distribuzione dell'età significa concepire l'età come una distribuzione gaussiana , calcolandone i due parametri che la caratterizzano: Media e Deviazione standard.

# %%
#NOTA1: dfAgeSexPclassStat[dfAgeSexPclassStat.index.values[i]]
#NOTA2: dfAgeSexPclassStat.loc[0][0:3] seleziona Mean e StdDev per gli uomini

# %%
df_AgeSexPclassMean=df_data_1.groupby((['Sex', 'Pclass'])).mean()['Age']
df_AgeSexPclassMean=df_AgeSexPclassMean.rename('Mean')
df_AgeSexPclassStd=df_data_1.groupby((['Sex', 'Pclass'])).std()['Age']
df_AgeSexPclassStd=df_AgeSexPclassStd.rename('StdDev')

# %%
dfAgeSexPclassStat = pd.concat([df_AgeSexPclassMean,df_AgeSexPclassStd] , axis = 1)
dfAgeSexPclassStat
# Out:
#                  Mean     StdDev
# Sex Pclass
# 0   1       41.181117  13.387543
#     2       30.715380  13.436893
#     3       25.681197   9.834920
# 1   1       36.958333  13.715325
#     2       27.513396  12.726230
#     3       22.130417  10.228949

# %% [markdown]
# Calcolo le percentuali di uomini e donne per classe e modifico il nome della serie

# %%
d_Male_Pclass  = {"Male Pass. Perc. per Class":[sr_Sex_Pclass1[0],sr_Sex_Pclass2[0],sr_Sex_Pclass3[0]]}
sr_Male_Pclass = pd.DataFrame(data=d_Male_Pclass , index = [1,2,3])
sr_Male_Pclass_perc = (sr_Male_Pclass/len(df_data_1))*100

# %%
d_Female_Pclass  = {"Female Pass. Perc. per Class":[sr_Sex_Pclass1[1],sr_Sex_Pclass2[1],sr_Sex_Pclass3[1]]}
sr_Female_Pclass = pd.DataFrame(data=d_Female_Pclass , index = [1,2,3])
sr_Female_Pclass_perc = (sr_Female_Pclass/len(df_data_1))*100

# %% [markdown]
# Modifico la label di media e deviazione standard per uomini e donne per classe

# %%
sr_Male_Pclass_Age_Mean = dfAgeSexPclassStat.loc[0]['Mean']
sr_Male_Pclass_Age_Mean = sr_Male_Pclass_Age_Mean.rename("Male Pass. Age Mean per Class")
sr_Male_Pclass_Age_Std = dfAgeSexPclassStat.loc[0]['StdDev']
sr_Male_Pclass_Age_Std = sr_Male_Pclass_Age_Std.rename("Male Pass. Age Std per Class")

# %%
sr_Female_Pclass_Age_Mean = dfAgeSexPclassStat.loc[1]['Mean']
sr_Female_Pclass_Age_Mean = sr_Female_Pclass_Age_Mean.rename("Female Pass. Age Mean per Class")
sr_Female_Pclass_Age_Std = dfAgeSexPclassStat.loc[1]['StdDev']
sr_Female_Pclass_Age_Std = sr_Female_Pclass_Age_Std.rename("Female Pass. Age Std per Class")

# %%
df_Sex_Pclass  = pd.concat([sr_Male_Pclass_perc , 
                             sr_Male_Pclass_Age_Mean , 
                             sr_Male_Pclass_Age_Std ,
                             sr_Female_Pclass_perc  , 
                             sr_Female_Pclass_Age_Mean  , 
                             sr_Female_Pclass_Age_Std  ] , axis = 1)
                            
 
df_Sex_Pclass
# Out:
#    Male Pass. Perc. per Class  Male Pass. Age Mean per Class  \
# 1                   13.674561                      41.181117
# 2                   13.063407                      30.715380
# 3                   37.662338                      25.681197
#
#    Male Pass. Age Std per Class  Female Pass. Perc. per Class  \
# 1                     13.387543                     11.000764
# 2                     13.436893                      8.097785
# 3                      9.834920                     16.501146
#
#    Female Pass. Age Mean per Class  Female Pass. Age Std per Class
# 1                        36.958333                       13.715325
# 2                        27.513396                       12.726230
# 3                        22.130417                       10.228949

# %% [markdown]
# In basso è rappresentata la percentuale di passeggeri per classe e sesso in modo visivo. Dal grafico si evidenzia che:
# <ul>
#     <li>La terza classe è il 44% dei passeggeri. I maschi sono poco più del doppio delle donne.</li>
#     <li>La seconda classe è il 21% dei passeggeri. I maschi sono 1/3 in più rispetto alle donne.</li>
#     <li>La prima classe è 24% dei passeggeri. I maschi sono 1/5 in più rispetto alle donne.</li>
# </ul>
# Questi risultati sono una conferma del fatto che gli immigranti erano una componente preponderante dei passeggeri.

# %%
dimensions = (8, 5)
fig, ax = plt.subplots(figsize=dimensions)
labels = ["Class 1","Class 2","Class 3"]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
bars_1=ax.bar( x - width/2, df_Sex_Pclass["Male Pass. Perc. per Class"], width, label='Male')
bars_2=ax.bar( x + width/2, df_Sex_Pclass["Female Pass. Perc. per Class"], width, label='Female')

ax.set_ylabel('Percentage')
ax.set_title('Male and female passengers percentage per class')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar_label(bars_1, padding=3)
ax.bar_label(bars_2, padding=3)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# In basso è rappresentata l'età media dei passeggeri per classe e sesso in modo visivo. Dal grafico si evidenzia che:
# <ul>
#     <li>La differenza d'età tra uomini e donne è di 4 anni indipendentemente dalla classe</li>
#     <li>La media d'età è descrescente man mano che si abbassa il livello della classe sociale. Questo rafforza ancora una volta la considerazione che i giovani è più probabile che siano immigranti. Però potrebbe anche essere che la media è abbassata da eventuali figli a carico.</li>
# </ul>
# Questa distribuzione dei dati conferma la correlazione che avevo trovato inizialmente tra età e classe.

# %%
dimensions = (8, 5)
fig, ax = plt.subplots(figsize=dimensions)
labels = ["Class 1","Class 2","Class 3"]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
bars_1=ax.bar( x - width/2, df_Sex_Pclass["Male Pass. Age Mean per Class"], width, label='Male')
bars_2=ax.bar( x + width/2, df_Sex_Pclass["Female Pass. Age Mean per Class"], width, label='Female')

ax.set_ylabel('Mean age by sex and class')
ax.set_title('Male and female passengers age mean per class')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar_label(bars_1, padding=3)
ax.bar_label(bars_2, padding=3)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# Nel prossimo grafico invece è rappresentata la deviazione standard dell'età per classe e sesso. Si evince che:
# <ul>
#     <li>la differenza di deviazione standard tra la distribuzione d'età di uomini e donne appartenenti alla medesima classe è piuttosto labile. Proviamo a fare il rapporto tra le deviazioni per classe:</li>
#     <ul>
#         <li>Classe 1 : 0.98</li>
#         <li>Classe 2 : 0.92</li>
#         <li>Classe 3 : 0.96</li>
#     </ul>
#     <li>la differenza di deviazione tra la Classe 1 e la Classe 2 è di meno di un anno </li>
#     <li>la differenza di deviazione tra la Classe 2 e la Classe 3 è di un circa 3 anni </li>
#
# </ul>
# Per comprendere meglio il significato che la deviazione standard racchiude, vi ricordo due cose:
# <ul>
#     <li>la deviazione standard è la variazione media rispetto alla media. Il valore di deviazione non è nient'altro che la variazione in anni media rispetto alla media degli anni.</li>
#     <li>un range intorno alla media di una deviazione standard racchiude il 68% dei dati. Un range di due deviazioni standard racchiude il 95% dei dati.</li>
# </ul>

# %%
dimensions = (7, 5)
fig, ax = plt.subplots(figsize=dimensions)
labels = ["Class 1","Class 2","Class 3"]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
bars_1=ax.bar( x - width/2, df_Sex_Pclass["Male Pass. Age Std per Class"], width, label='Male')
bars_2=ax.bar( x + width/2, df_Sex_Pclass["Female Pass. Age Std per Class"], width, label='Female')

ax.set_ylabel('Mean age by sex and class')
ax.set_title('Male and female passengers age deviation per class')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar_label(bars_1, padding=3)
ax.bar_label(bars_2, padding=3)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# 4.4 Relation between Sex, Class and Survived
# ---

# %% [markdown]
# Per i sopravvissuti ho deciso di utlizzare solo i dati di train dato che i dati di test non sono etichettati

# %%
df_data_train['Survived'] = df_data_train['Survived'].astype("int64")

# %%
df_data_train_1 = df_data_train.copy()

# %% [markdown]
# Un altro check che possiamo fare è capire qual'è la percentuale di sopravvissuti per classe e pe sesso.

# %%
sr_Survived_Sex_Class = df_data_train_1.groupby(['Sex','Pclass']).Survived.apply((lambda x: (x==1).sum()))
sr_NotSurvived_Sex_Class = df_data_train_1.groupby(['Sex','Pclass']).Survived.apply((lambda x: (x==0).sum()))
sr_SurvivedRatio_Sex_Class = sr_Survived_Sex_Class/(sr_NotSurvived_Sex_Class+sr_Survived_Sex_Class)
df_SurvivedRatio_Sex_Class = pd.merge(sr_SurvivedRatio_Sex_Class[0],sr_SurvivedRatio_Sex_Class[1], left_index=True, right_index=True)
df_SurvivedRatio_Sex_Class = df_SurvivedRatio_Sex_Class.rename(columns={'Survived_x': "Male Ratio Survived per Class"}) 
df_SurvivedRatio_Sex_Class = df_SurvivedRatio_Sex_Class.rename(columns={'Survived_y': "Female Ratio Survived per Class"})

# %% [markdown]
# Nel grafico sotto ho voluto rappresentare la percentuale di sopravvivenza dei passeggeri divisa per classe e per sesso all'interno della classe. Questo significa che le percentuali che vedete sotto sono riferite al totale dei passeggeri per quella classe e per quel sesso. Vediamolo nel dettaglio:
#     <ul>
#          <li>Feature <b>Sex</b> : si vede chiaramente un netto divario tra la percentuale di sopravvissuti maschi e femmine. Nella Classe 1 il 97% delle femmine è sopravvissuto mentre dei maschi solo il 37%.</li>
#          <li>Feature <b>Class</b> : si denota una differenza nella sopravvivenza tra le femmine di prima e seconda classe e le femmine di terza classe. C'è anche una netta differenza tra i sopravvissuti maschi della prima classe e i sopravvissuti maschi di seconda e terza classe.</li>
#     </ul>

# %%
dimensions = (7, 5)
fig, ax = plt.subplots(figsize=dimensions)
labels = ["Class 1","Class 2","Class 3"]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
bars_1=ax.bar( x - width/2, df_SurvivedRatio_Sex_Class["Male Ratio Survived per Class"], width, label='Male')
bars_2=ax.bar( x + width/2, df_SurvivedRatio_Sex_Class["Female Ratio Survived per Class"], width, label='Female')

ax.set_ylabel('Percentage')
ax.set_title('Survived Percentage by Sex and Class')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.bar_label(bars_1, padding=3)
ax.bar_label(bars_2, padding=3)
ax.legend()
fig.tight_layout()
plt.show()

# %%
category_train = pd.cut(df_data_train_1.Age,bins=[0,2,17,65,99],labels=['Toddler/baby','Child','Adult','Elderly'])
df_data_train_1.insert(5,'Age Group',category_train)

category_all = pd.cut(df_data_1.Age,bins=[0,2,17,65,99],labels=['0','1','2','3'])
df_data_1.insert(5,'Age Group',category_all)

# %%
df_data_1.head()
# Out:
#     Age Cabin  Embarked     Fare  \
# 0  22.0   NaN       2.0   7.2500
# 1  38.0   C85       0.0  71.2833
# 2  26.0   NaN       2.0   7.9250
# 3  35.0  C123       2.0  53.1000
# 4  35.0   NaN       2.0   8.0500
#
#                                                 Name Age Group  Parch  \
# 0                            Braund, Mr. Owen Harris         2      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         2      0
# 2                             Heikkinen, Miss. Laina         2      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         2      0
# 4                           Allen, Mr. William Henry         2      0
#
#    PassengerId  Pclass  Sex  SibSp  Survived            Ticket
# 0            1       3    0      1       0.0         A/5 21171
# 1            2       1    1      1       1.0          PC 17599
# 2            3       3    1      0       1.0  STON/O2. 3101282
# 3            4       1    1      1       1.0            113803
# 4            5       3    0      0       0.0            373450

# %% [markdown]
# 4 Fare
# ---

# %%
mediana = df_data_1.groupby(['Pclass', 'Parch', 'SibSp']).Fare.median()[3][0][0]
df_data_1.Fare = df_data_1.Fare.fillna(mediana)

# %% [markdown]
# 5 Family
# ---

# %% [markdown]
# We will start by creating fields related to the family unit. The first of these will come from the SibSp and Parch fields, which we can remove later. This will reflect the size of passengers' family. We will also enter a field to indicate whether the passenger is travelling alone or not.

# %%
df_data_1['FamilySize'] = df_data_1.Parch + df_data_1.SibSp + 1
df_data_1['IsAlone'] = 0
df_data_1.loc[df_data_1['FamilySize'] == 1, 'IsAlone'] = 1
df_data_1 = df_data_1.drop(['Parch','SibSp'],axis = 1)

# %%
fig, axes = plt.subplots(figsize=(22,8), nrows = 1, ncols = 2)
ax = sns.countplot(x = 'FamilySize', hue='Survived', data = df_data_1, palette = ['#334550','#6D83AA'], ax = axes[0])
ax.set_title('Survival Rate per Family Size')
ax = sns.countplot(x = 'FamilySize', data = df_data_1, palette = ['#334550','#334668','#394184','#496595','#6D83AA','#91A2BF','#C8D0DF'], ax = axes[1])
_ = ax.set_title('Family Size Countplot')

# %%
df_data_1['GroupSize']
# Out:
# 0       1
# 1       2
# 2       1
# 3       2
# 4       1
#        ..
# 1304    1
# 1305    3
# 1306    1
# 1307    1
# 1308    3
# Name: GroupSize, Length: 1309, dtype: int64

# %%
df_data_1['Surname'] = df_data_1['Name'].str.split(', ', expand=True)[0]
df_data_1['Title'] =  df_data_1['Name'].str.split(', ', expand=True)[1].str.split('. ', expand=True)[0]

# Create a new feature identifying children (15 or younger)
df_data_1['IsChild'] = np.where(df_data_1['Age'] < 16, 1, 0)

# %% [markdown]
# Grouping Families and Travellers
# Sorting the data by Ticket, one finds that multiple passengers share the same ticket number. This can be used as a basis for grouping passengers that travelled together. It will also be useful to distinguish whether these passenger groups are immediate-related (1st-degree) families, entirely unrelated or non-immediate (e.g. friends, cousins), or a mix. We will also identify passengers who are travelling alone. We define:
#
# <ul>
#         <li> GroupID: an integer label uniquely identifying each group; a surrogate to Ticket.</li>
#         <li>GroupSize: total number of passengers sharing a ticket.</li>
#         <li>GroupType: categorization of group into 'Family', 'Non-Family', 'Mixed', 'IsAlone'.</li>
#         <li>GroupNumSurvived: number of members in that group which are known to have survived.</li>
#         <li>GroupNumPerished: number of members in that group which are known to have perished.</li>
# </ul>

# %%
# Create mappings for assigning GroupID, GroupType, GroupSize, GroupNumSurvived, 
# and GroupNumPerished 
group_id = 1 
ticket_to_group_id = {} 
ticket_to_group_type = {}  
ticket_to_group_size = {}  
ticket_to_group_num_survived = {}
ticket_to_group_num_perished = {}
for (ticket, group) in df_data_1.groupby('Ticket'):
    #print(str(ticket)+str(group))
    # Categorize group type (Family, Non-Family, Mixed, )
    num_names = len(set(group['Surname'].values))  # number of unique names in this group
    group_size = len(group['Surname'].values)  # total size of this group
    if group_size > 1:
        if num_names == 1:
            ticket_to_group_type[ticket] = 'Family'
        elif num_names == group_size:
            ticket_to_group_type[ticket] = 'NonFamily'
        else:
            ticket_to_group_type[ticket] = 'Mixed'
    else:
        ticket_to_group_type[ticket] = 'IsAlone'
            
    # assign group size and grouop identifier
    ticket_to_group_size[ticket] = group_size
    ticket_to_group_id[ticket] = group_id
    ticket_to_group_num_survived[ticket] = group[group['Survived'] == 1]['Survived'].count()
    ticket_to_group_num_perished[ticket] = group[group['Survived'] == 0]['Survived'].count()
    group_id += 1
    
# Apply the mappings we've just defined to create the GroupID and GroupType variables
df_data_1['GroupID'] = df_data_1['Ticket'].map(ticket_to_group_id)
df_data_1['GroupSize'] = df_data_1['Ticket'].map(ticket_to_group_size)    
df_data_1['GroupType'] = df_data_1['Ticket'].map(ticket_to_group_type)  
df_data_1['GroupNumSurvived'] = df_data_1['Ticket'].map(ticket_to_group_num_survived)
df_data_1['GroupNumPerished'] = df_data_1['Ticket'].map(ticket_to_group_num_perished)

# Let's print the first 4 group entries to check that our grouping was successful
counter = 1
break_point = 4
feature_list = ['Surname', 'FamilySize','Ticket','GroupID','GroupType', 'GroupSize']
print('Printing Sample Data Entries to Verify Grouping:\n')
for (ticket, group) in df_data_1.groupby('Ticket'):
    print('\n', group[feature_list])
    if counter == break_point:
        break
    counter += 1

# Let's also check that GroupNumSurvived and GroupNumPerished were created accurately
feature_list = ['GroupID', 'GroupSize', 'Survived','GroupNumSurvived', 'GroupNumPerished']
df_data_1[feature_list].sort_values(by=['GroupID']).head(15)
# Out:
# 110152      Age Cabin  Embarked  Fare  \
# 257  30.0   B77       2.0  86.5
# 504  16.0   B79       2.0  86.5
# 759  33.0   B77       2.0  86.5
#
#                                                   Name Age Group  PassengerId  \
# 257                               Cherry, Miss. Gladys         2          258
# 504                              Maioni, Miss. Roberta         1          505
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...         2          760
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 257       1    1       1.0  110152    B           1        1  Cherry  Miss
# 504       1    1       1.0  110152    B           1        1  Maioni  Miss
# 759       1    1       1.0  110152    B           1        1  Rothes    th
#
#      IsChild
# 257        0
# 504        0
# 759        0
# 110413      Age Cabin  Embarked   Fare                                    Name  \
# 262  52.0   E67       2.0  79.65                       Taussig, Mr. Emil
# 558  39.0   E67       2.0  79.65  Taussig, Mrs. Emil (Tillie Mandelbaum)
# 585  18.0   E68       2.0  79.65                     Taussig, Miss. Ruth
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 262         2          263       1    0       0.0  110413    E           3
# 558         2          559       1    1       1.0  110413    E           3
# 585         2          586       1    1       1.0  110413    E           3
#
#      IsAlone  Surname Title  IsChild
# 262        0  Taussig    Mr        0
# 558        0  Taussig   Mrs        0
# 585        0  Taussig  Miss        0
# 110465      Age Cabin  Embarked  Fare                            Name Age Group  \
# 110  47.0  C110       2.0  52.0  Porter, Mr. Walter Chamberlain         2
# 475  42.0   A14       2.0  52.0     Clifford, Mr. George Quincy         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 110          111       1    0       0.0  110465    C           1        1
# 475          476       1    0       0.0  110465    A           1        1
#
#       Surname Title  IsChild
# 110    Porter    Mr        0
# 475  Clifford    Mr        0
# 110469       Age Cabin  Embarked  Fare                      Name Age Group  \
# 1226  30.0  C106       2.0  26.0  Maguire, Mr. John Edward         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1226         1227       1    0       NaN  110469    C           1        1
#
#       Surname Title  IsChild
# 1226  Maguire    Mr        0
# 110489       Age Cabin  Embarked   Fare                      Name Age Group  \
# 1049  42.0   D22       2.0  26.55  Borebank, Mr. John James         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1049         1050       1    0       NaN  110489    D           1        1
#
#        Surname Title  IsChild
# 1049  Borebank    Mr        0
# 110564      Age Cabin  Embarked   Fare                                       Name  \
# 430  28.0   C52       2.0  26.55  Bjornstrom-Steffansson, Mr. Mauritz Hakan
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 430         2          431       1    0       1.0  110564    C           1
#
#      IsAlone                 Surname Title  IsChild
# 430        1  Bjornstrom-Steffansson    Mr        0
# 110813       Age Cabin  Embarked   Fare  \
# 366   60.0   D37       0.0  75.25
# 1127  64.0   D37       0.0  75.25
#
#                                                   Name Age Group  PassengerId  \
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)         2          367
# 1127                          Warren, Mr. Frank Manley         2         1128
#
#       Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 366        1    1       1.0  110813    D           2        0  Warren   Mrs
# 1127       1    0       NaN  110813    D           2        0  Warren    Mr
#
#       IsChild
# 366         0
# 1127        0
# 111163       Age Cabin  Embarked  Fare                    Name Age Group  \
# 1082  42.0   NaN       2.0  26.0  Salomon, Mr. Abraham L         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1082         1083       1    0       NaN  111163    Z           1        1
#
#       Surname Title  IsChild
# 1082  Salomon    Mr        0
# 111240      Age Cabin  Embarked  Fare                       Name Age Group  \
# 170  61.0   B19       2.0  33.5  Van der hoef, Mr. Wyckoff         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 170          171       1    0       0.0  111240    B           1        1
#
#           Surname Title  IsChild
# 170  Van der hoef    Mr        0
# 111320      Age Cabin  Embarked  Fare               Name Age Group  PassengerId  \
# 462  47.0   E63       2.0  38.5  Gee, Mr. Arthur H         2          463
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 462       1    0       0.0  111320    E           1        1     Gee    Mr
#
#      IsChild
# 462        0
# 111361      Age Cabin  Embarked     Fare  \
# 329  16.0   B18       0.0  57.9792
# 523  44.0   B18       0.0  57.9792
#
#                                                 Name Age Group  PassengerId  \
# 329                     Hippach, Miss. Jean Gertrude         1          330
# 523  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)         2          524
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 329       1    1       1.0  111361    B           2        0  Hippach  Miss
# 523       1    1       1.0  111361    B           2        0  Hippach   Mrs
#
#      IsChild
# 329        0
# 523        0
# 111369      Age Cabin  Embarked  Fare                   Name Age Group  PassengerId  \
# 889  26.0  C148       0.0  30.0  Behr, Mr. Karl Howell         2          890
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 889       1    0       1.0  111369    C           1        1    Behr    Mr
#
#      IsChild
# 889        0
# 111426      Age Cabin  Embarked   Fare                             Name Age Group  \
# 604  35.0   NaN       0.0  26.55  Homer, Mr. Harry ("Mr E Haven")         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 604          605       1    0       1.0  111426    Z           1        1
#
#     Surname Title  IsChild
# 604   Homer    Mr        0
# 111427      Age Cabin  Embarked   Fare  \
# 507  42.0   NaN       2.0  26.55
#
#                                               Name Age Group  PassengerId  \
# 507  Bradley, Mr. George ("George Arthur Brayton")         2          508
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 507       1    0       1.0  111427    Z           1        1  Bradley    Mr
#
#      IsChild
# 507        0
# 111428      Age Cabin  Embarked   Fare  \
# 187  45.0   NaN       2.0  26.55
#
#                                               Name Age Group  PassengerId  \
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")         2          188
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 187       1    0       1.0  111428    Z           1        1  Romaine    Mr
#
#      IsChild
# 187        0
# 112050      Age Cabin  Embarked  Fare                    Name Age Group  \
# 806  39.0   A36       2.0   0.0  Andrews, Mr. Thomas Jr         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 806          807       1    0       0.0  112050    A           1        1
#
#      Surname Title  IsChild
# 806  Andrews    Mr        0
# 112051       Age Cabin  Embarked  Fare                                   Name  \
# 1157  42.0   NaN       2.0   0.0  Chisholm, Mr. Roderick Robert Crispin
#
#      Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 1157         2         1158       1    0       NaN  112051    Z           1
#
#       IsAlone   Surname Title  IsChild
# 1157        1  Chisholm    Mr        0
# 112052      Age Cabin  Embarked  Fare                           Name Age Group  \
# 633  42.0   NaN       2.0   0.0  Parr, Mr. William Henry Marsh         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 633          634       1    0       0.0  112052    Z           1        1
#
#     Surname Title  IsChild
# 633    Parr    Mr        0
# 112053      Age Cabin  Embarked  Fare                          Name Age Group  \
# 887  19.0   B42       2.0  30.0  Graham, Miss. Margaret Edith         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 887          888       1    1       1.0  112053    B           1        1
#
#     Surname Title  IsChild
# 887  Graham  Miss        0
# 112058       Age        Cabin  Embarked  Fare                     Name Age Group  \
# 815   42.0         B102       2.0   0.0         Fry, Mr. Richard         2
# 1263  49.0  B52 B54 B56       2.0   0.0  Ismay, Mr. Joseph Bruce         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 815           816       1    0       0.0  112058    B           1        1
# 1263         1264       1    0       NaN  112058    B           1        1
#
#      Surname Title  IsChild
# 815      Fry    Mr        0
# 1263   Ismay    Mr        0
# 112059      Age Cabin  Embarked  Fare                   Name Age Group  PassengerId  \
# 263  40.0   B94       2.0   0.0  Harrison, Mr. William         2          264
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 263       1    0       0.0  112059    B           1        1  Harrison    Mr
#
#      IsChild
# 263        0
# 112277      Age Cabin  Embarked  Fare              Name Age Group  PassengerId  \
# 209  40.0   A31       0.0  31.0  Blank, Mr. Henry         2          210
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 209       1    0       1.0  112277    A           1        1   Blank    Mr
#
#      IsChild
# 209        0
# 112377       Age Cabin  Embarked     Fare  \
# 1131  55.0   NaN       0.0  27.7208
#
#                                            Name Age Group  PassengerId  \
# 1131  Lindstrom, Mrs. Carl Johan (Sigrid Posse)         2         1132
#
#       Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone    Surname  \
# 1131       1    1       NaN  112377    Z           1        1  Lindstrom
#
#      Title  IsChild
# 1131   Mrs        0
# 112378       Age Cabin  Embarked  Fare                                     Name  \
# 1259  45.0   NaN       0.0  59.4  Gibson, Mrs. Leonard (Pauline C Boeson)
# 1293  22.0   NaN       0.0  59.4           Gibson, Miss. Dorothy Winifred
#
#      Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 1259         2         1260       1    1       NaN  112378    Z           2
# 1293         2         1294       1    1       NaN  112378    Z           2
#
#       IsAlone Surname Title  IsChild
# 1259        0  Gibson   Mrs        0
# 1293        0  Gibson  Miss        0
# 112379      Age Cabin  Embarked  Fare                       Name Age Group  \
# 766  42.0   NaN       0.0  39.6  Brewe, Dr. Arthur Jackson         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 766          767       1    0       0.0  112379    Z           1        1
#
#     Surname Title  IsChild
# 766   Brewe    Dr        0
# 112901       Age Cabin  Embarked   Fare  \
# 1196  64.0   B26       2.0  26.55
#
#                                                    Name Age Group  \
# 1196  Crosby, Mrs. Edward Gifford (Catherine Elizabe...         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1196         1197       1    1       NaN  112901    B           3        0
#
#      Surname Title  IsChild
# 1196  Crosby   Mrs        0
# 113028      Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 711  42.0  C124       2.0  26.55  Klaber, Mr. Herman         2          712
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 711       1    0       0.0  113028    C           1        1  Klaber    Mr
#
#      IsChild
# 711        0
# 113038       Age Cabin  Embarked  Fare                   Name Age Group  \
# 1106  42.0   B11       2.0  42.5  Head, Mr. Christopher         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1106         1107       1    0       NaN  113038    B           1        1
#
#      Surname Title  IsChild
# 1106    Head    Mr        0
# 113043      Age Cabin  Embarked  Fare                 Name Age Group  PassengerId  \
# 331  45.5  C124       2.0  28.5  Partner, Mr. Austen         2          332
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 331       1    0       0.0  113043    C           1        1  Partner    Mr
#
#      IsChild
# 331        0
# 113044       Age Cabin  Embarked  Fare                      Name Age Group  \
# 1246  50.0   E60       2.0  26.0  Julian, Mr. Henry Forbes         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1246         1247       1    0       NaN  113044    E           1        1
#
#      Surname Title  IsChild
# 1246  Julian    Mr        0
# 113050      Age Cabin  Embarked   Fare                               Name Age Group  \
# 536  45.0   B38       2.0  26.55  Butt, Major. Archibald Willingham         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 536          537       1    0       0.0  113050    B           1        1
#
#     Surname  Title  IsChild
# 536    Butt  Major        0
# 113051      Age Cabin  Embarked   Fare                             Name Age Group  \
# 452  30.0  C111       0.0  27.75  Foreman, Mr. Benjamin Laventall         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 452          453       1    0       0.0  113051    C           1        1
#
#      Surname Title  IsChild
# 452  Foreman    Mr        0
# 113054      Age Cabin  Embarked  Fare                     Name Age Group  \
# 919  41.0   A21       2.0  30.5  Brady, Mr. John Bertram         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 919          920       1    0       NaN  113054    A           1        1
#
#     Surname Title  IsChild
# 919   Brady    Mr        0
# 113055      Age Cabin  Embarked   Fare                    Name Age Group  \
# 857  51.0   E17       2.0  26.55  Daly, Mr. Peter Denis          2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 857          858       1    0       1.0  113055    E           1        1
#
#     Surname Title  IsChild
# 857    Daly    Mr        0
# 113056      Age Cabin  Embarked  Fare                        Name Age Group  \
# 284  42.0   A19       2.0  26.0  Smith, Mr. Richard William         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 284          285       1    0       0.0  113056    A           1        1
#
#     Surname Title  IsChild
# 284   Smith    Mr        0
# 113059       Age Cabin  Embarked  Fare                     Name Age Group  \
# 83    28.0   NaN       2.0  47.1  Carrau, Mr. Francisco M         2
# 1294  17.0   NaN       2.0  47.1   Carrau, Mr. Jose Pedro         1
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 83             84       1    0       0.0  113059    Z           1        1
# 1294         1295       1    0       NaN  113059    Z           1        1
#
#      Surname Title  IsChild
# 83    Carrau    Mr        0
# 1294  Carrau    Mr        0
# 113501      Age Cabin  Embarked  Fare                    Name Age Group  \
# 782  29.0    D6       2.0  30.0  Long, Mr. Milton Clyde         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 782          783       1    0       0.0  113501    D           1        1
#
#     Surname Title  IsChild
# 782    Long    Mr        0
# 113503       Age Cabin  Embarked   Fare  \
# 377   27.0   C82       0.0  211.5
# 965   35.0  C130       0.0  211.5
# 966   32.5  C132       0.0  211.5
# 1109  50.0   C80       0.0  211.5
# 1298  50.0   C80       0.0  211.5
#
#                                               Name Age Group  PassengerId  \
# 377                      Widener, Mr. Harry Elkins         2          378
# 965                           Geiger, Miss. Amalie         2          966
# 966                             Keeping, Mr. Edwin         2          967
# 1109  Widener, Mrs. George Dunton (Eleanor Elkins)         2         1110
# 1298                    Widener, Mr. George Dunton         2         1299
#
#       Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 377        1    0       0.0  113503    C           3        0  Widener    Mr
# 965        1    1       NaN  113503    C           1        1   Geiger  Miss
# 966        1    0       NaN  113503    C           1        1  Keeping    Mr
# 1109       1    1       NaN  113503    C           3        0  Widener   Mrs
# 1298       1    0       NaN  113503    C           3        0  Widener    Mr
#
#       IsChild
# 377         0
# 965         0
# 966         0
# 1109        0
# 1298        0
# 113505      Age Cabin  Embarked  Fare                                    Name  \
# 166  36.0   E33       2.0  55.0  Chibnall, Mrs. (Edith Martha Bowerman)
# 356  22.0   E33       2.0  55.0             Bowerman, Miss. Elsie Edith
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 166         2          167       1    1       1.0  113505    E           2
# 356         2          357       1    1       1.0  113505    E           2
#
#      IsAlone   Surname Title  IsChild
# 166        0  Chibnall   Mrs        0
# 356        0  Bowerman  Miss        0
# 113509      Age Cabin  Embarked     Fare                            Name Age Group  \
# 54   65.0   B30       0.0  61.9792  Ostby, Mr. Engelhart Cornelius         2
# 917  22.0   B36       0.0  61.9792    Ostby, Miss. Helene Ragnhild         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 54            55       1    0       0.0  113509    B           2        0
# 917          918       1    1       NaN  113509    B           2        0
#
#     Surname Title  IsChild
# 54    Ostby    Mr        0
# 917   Ostby  Miss        0
# 113510      Age Cabin  Embarked  Fare                                    Name  \
# 351  42.0  C128       2.0  35.0  Williams-Lambert, Mr. Fletcher Fellows
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 351         2          352       1    0       0.0  113510    C           1
#
#      IsAlone           Surname Title  IsChild
# 351        1  Williams-Lambert    Mr        0
# 113514      Age Cabin  Embarked   Fare                       Name Age Group  \
# 252  62.0   C87       2.0  26.55  Stead, Mr. William Thomas         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 252          253       1    0       0.0  113514    C           1        1
#
#     Surname Title  IsChild
# 252   Stead    Mr        0
# 113572      Age Cabin  Embarked  Fare                                       Name  \
# 61   38.0   B28       2.0  80.0                        Icard, Miss. Amelie
# 829  62.0   B28       2.0  80.0  Stone, Mrs. George Nelson (Martha Evelyn)
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 61          2           62       1    1       1.0  113572    B           1
# 829         2          830       1    1       1.0  113572    B           1
#
#      IsAlone Surname Title  IsChild
# 61         1   Icard  Miss        0
# 829        1   Stone   Mrs        0
# 113760      Age    Cabin  Embarked   Fare  \
# 390  36.0  B96 B98       2.0  120.0
# 435  14.0  B96 B98       2.0  120.0
# 763  36.0  B96 B98       2.0  120.0
# 802  11.0  B96 B98       2.0  120.0
#
#                                           Name Age Group  PassengerId  Pclass  \
# 390                 Carter, Mr. William Ernest         2          391       1
# 435                  Carter, Miss. Lucile Polk         1          436       1
# 763  Carter, Mrs. William Ernest (Lucile Polk)         2          764       1
# 802        Carter, Master. William Thornton II         1          803       1
#
#      Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname   Title  IsChild
# 390    0       1.0  113760    B           4        0  Carter      Mr        0
# 435    1       1.0  113760    B           4        0  Carter    Miss        1
# 763    1       1.0  113760    B           4        0  Carter     Mrs        0
# 802    0       1.0  113760    B           4        0  Carter  Master        1
# 113767      Age Cabin  Embarked  Fare                   Name Age Group  PassengerId  \
# 185  42.0   A32       2.0  50.0  Rood, Mr. Hugh Roscoe         2          186
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 185       1    0       0.0  113767    A           1        1    Rood    Mr
#
#      IsChild
# 185        0
# 113773       Age Cabin  Embarked  Fare  \
# 748   19.0   D30       2.0  53.1
# 1073  18.0   D30       2.0  53.1
#
#                                                    Name Age Group  \
# 748                           Marvin, Mr. Daniel Warner         2
# 1073  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 748           749       1    0       0.0  113773    D           2        0
# 1073         1074       1    1       NaN  113773    D           2        0
#
#      Surname Title  IsChild
# 748   Marvin    Mr        0
# 1073  Marvin   Mrs        0
# 113776      Age Cabin  Embarked  Fare                               Name Age Group  \
# 151  22.0    C2       2.0  66.6  Pears, Mrs. Thomas (Edith Wearne)         2
# 336  29.0    C2       2.0  66.6          Pears, Mr. Thomas Clinton         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 151          152       1    1       1.0  113776    C           2        0
# 336          337       1    0       0.0  113776    C           2        0
#
#     Surname Title  IsChild
# 151   Pears   Mrs        0
# 336   Pears    Mr        0
# 113778      Age Cabin  Embarked   Fare                         Name Age Group  \
# 932  42.0   D34       2.0  26.55  Franklin, Mr. Thomas Parham         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 932          933       1    0       NaN  113778    D           1        1
#
#       Surname Title  IsChild
# 932  Franklin    Mr        0
# 113780       Age Cabin  Embarked  Fare                       Name Age Group  \
# 1022  53.0   C51       0.0  28.5  Gracie, Col. Archibald IV         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1022         1023       1    0       NaN  113780    C           1        1
#
#      Surname Title  IsChild
# 1022  Gracie   Col        0
# 113781        Age    Cabin  Embarked    Fare  \
# 297    2.00  C22 C26       2.0  151.55
# 305    0.92  C22 C26       2.0  151.55
# 498   25.00  C22 C26       2.0  151.55
# 708   22.00      NaN       2.0  151.55
# 1032  33.00      NaN       2.0  151.55
# 1197  30.00  C22 C26       2.0  151.55
#
#                                                  Name Age Group  PassengerId  \
# 297                      Allison, Miss. Helen Loraine         0          298
# 305                    Allison, Master. Hudson Trevor         0          306
# 498   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         2          499
# 708                              Cleaver, Miss. Alice         2          709
# 1032                             Daniels, Miss. Sarah         2         1033
# 1197             Allison, Mr. Hudson Joshua Creighton         2         1198
#
#       Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  Surname  \
# 297        1    1       0.0  113781    C           4        0  Allison
# 305        1    0       1.0  113781    C           4        0  Allison
# 498        1    1       0.0  113781    C           4        0  Allison
# 708        1    1       1.0  113781    Z           1        1  Cleaver
# 1032       1    1       NaN  113781    Z           1        1  Daniels
# 1197       1    0       NaN  113781    C           4        0  Allison
#
#        Title  IsChild
# 297     Miss        1
# 305   Master        1
# 498      Mrs        0
# 708     Miss        0
# 1032    Miss        0
# 1197      Mr        0
# 113783     Age Cabin  Embarked   Fare                      Name Age Group  \
# 11  58.0  C103       2.0  26.55  Bonnell, Miss. Elizabeth         2
#
#     PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 11           12       1    1       1.0  113783    C           1        1
#
#     Surname Title  IsChild
# 11  Bonnell  Miss        0
# 113784      Age Cabin  Embarked  Fare                          Name Age Group  \
# 339  45.0     T       2.0  35.5  Blackwell, Mr. Stephen Weart         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 339          340       1    0       0.0  113784    T           1        1
#
#        Surname Title  IsChild
# 339  Blackwell    Mr        0
# 113786      Age Cabin  Embarked  Fare                            Name Age Group  \
# 449  52.0  C104       2.0  30.5  Peuchen, Major. Arthur Godfrey         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 449          450       1    0       1.0  113786    C           1        1
#
#      Surname  Title  IsChild
# 449  Peuchen  Major        0
# 113787      Age Cabin  Embarked  Fare                        Name Age Group  \
# 492  55.0   C30       2.0  30.5  Molson, Mr. Harry Markland         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 492          493       1    0       0.0  113787    C           1        1
#
#     Surname Title  IsChild
# 492  Molson    Mr        0
# 113788     Age Cabin  Embarked  Fare                          Name Age Group  \
# 23  28.0    A6       2.0  35.5  Sloper, Mr. William Thompson         2
#
#     PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 23           24       1    0       1.0  113788    A           1        1
#
#    Surname Title  IsChild
# 23  Sloper    Mr        0
# 113789      Age Cabin  Embarked  Fare  \
# 35   42.0   NaN       2.0  52.0
# 383  35.0   NaN       2.0  52.0
#
#                                                   Name Age Group  PassengerId  \
# 35                      Holverson, Mr. Alexander Oskar         2           36
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...         2          384
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone    Surname Title  \
# 35        1    0       0.0  113789    Z           2        0  Holverson    Mr
# 383       1    1       1.0  113789    Z           2        0  Holverson   Mrs
#
#      IsChild
# 35         0
# 383        0
# 113790       Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 1214  33.0   NaN       2.0  26.55  Rowe, Mr. Alfred G         2         1215
#
#       Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 1214       1    0       NaN  113790    Z           1        1    Rowe    Mr
#
#       IsChild
# 1214        0
# 113791       Age Cabin  Embarked   Fare                       Name Age Group  \
# 1039  42.0   NaN       2.0  26.55  Crafton, Mr. John Bertram         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1039         1040       1    0       NaN  113791    Z           1        1
#
#       Surname Title  IsChild
# 1039  Crafton    Mr        0
# 113792      Age Cabin  Embarked   Fare                        Name Age Group  \
# 467  56.0   NaN       2.0  26.55  Smart, Mr. John Montgomery         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 467          468       1    0       0.0  113792    Z           1        1
#
#     Surname Title  IsChild
# 467   Smart    Mr        0
# 113794      Age Cabin  Embarked   Fare                         Name Age Group  \
# 447  34.0   NaN       2.0  26.55  Seward, Mr. Frederic Kimber         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 447          448       1    0       1.0  113794    Z           1        1
#
#     Surname Title  IsChild
# 447  Seward    Mr        0
# 113795       Age Cabin  Embarked   Fare                      Name Age Group  \
# 1122  21.0   NaN       2.0  26.55  Willard, Miss. Constance         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1122         1123       1    1       NaN  113795    Z           1        1
#
#       Surname Title  IsChild
# 1122  Willard  Miss        0
# 113796      Age Cabin  Embarked  Fare                            Name Age Group  \
# 602  42.0   NaN       2.0  42.4       Harrington, Mr. Charles H         2
# 958  47.0   NaN       2.0  42.4  Moore, Mr. Clarence Bloomfield         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 602          603       1    0       0.0  113796    Z           1        1
# 958          959       1    0       NaN  113796    Z           1        1
#
#         Surname Title  IsChild
# 602  Harrington    Mr        0
# 958       Moore    Mr        0
# 113798      Age Cabin  Embarked  Fare                     Name Age Group  \
# 270  42.0   NaN       2.0  31.0    Cairns, Mr. Alexander         2
# 842  30.0   NaN       0.0  31.0  Serepeca, Miss. Augusta         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 270          271       1    0       0.0  113798    Z           1        1
# 842          843       1    1       1.0  113798    Z           1        1
#
#       Surname Title  IsChild
# 270    Cairns    Mr        0
# 842  Serepeca  Miss        0
# 113800      Age Cabin  Embarked   Fare             Name Age Group  PassengerId  \
# 694  60.0   NaN       2.0  26.55  Weir, Col. John         2          695
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 694       1    0       0.0  113800    Z           1        1    Weir   Col
#
#      IsChild
# 694        0
# 113801       Age Cabin  Embarked  Fare                        Name Age Group  \
# 1189  30.0   NaN       2.0  45.5  Loring, Mr. Joseph Holland         2
#
#       PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 1189         1190       1    0       NaN  113801    Z           1        1
#
#      Surname Title  IsChild
# 1189  Loring    Mr        0
# 113803      Age Cabin  Embarked  Fare                                          Name  \
# 3    35.0  C123       2.0  53.1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 137  37.0  C123       2.0  53.1                   Futrelle, Mr. Jacques Heath
#
#     Age Group  PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  \
# 3           2            4       1    1       1.0  113803    C           2
# 137         2          138       1    0       0.0  113803    C           2
#
#      IsAlone   Surname Title  IsChild
# 3          0  Futrelle   Mrs        0
# 137        0  Futrelle    Mr        0
# 113804      Age Cabin  Embarked  Fare                         Name Age Group  \
# 607  27.0   NaN       2.0  30.5  Daniel, Mr. Robert Williams         2
#
#      PassengerId  Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone  \
# 607          608       1    0       1.0  113804    Z           1        1
#
#     Surname Title  IsChild
# 607  Daniel    Mr        0
# 113806      Age Cabin  Embarked  Fare  \
# 724  27.0    E8       2.0  53.1
# 809  33.0    E8       2.0  53.1
#
#                                                Name Age Group  PassengerId  \
# 724                   Chambers, Mr. Norman Campbell         2          725
# 809  Chambers, Mrs. Norman Campbell (Bertha Griggs)         2          810
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 724       1    0       1.0  113806    E           2        0  Chambers    Mr
# 809       1    1       1.0  113806    E           2        0  Chambers   Mrs
#
#      IsChild
# 724        0
# 809        0
# 113807      Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 555  62.0   NaN       2.0  26.55  Wright, Mr. George         2          556
#
#      Pclass  Sex  Survived  Ticket Deck  FamilySize  IsAlone Surname Title  \
# 555       1    0       0.0  113807    Z           1        1  Wright    Mr
#
#      IsChild
# 555        0
# 11668      Age Cabin  Embarked  Fare  \
# 41   27.0   NaN       2.0  21.0
# 117  29.0   NaN       2.0  21.0
#
#                                                   Name Age Group  PassengerId  \
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...         2           42
# 117                    Turpin, Mr. William John Robert         2          118
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone Surname Title  \
# 41        2    1       0.0  11668    Z           2        0  Turpin   Mrs
# 117       2    0       0.0  11668    Z           2        0  Turpin    Mr
#
#      IsChild
# 41         0
# 117        0
# 11751      Age Cabin  Embarked     Fare  \
# 248  37.0   D35       2.0  52.5542
# 871  47.0   D35       2.0  52.5542
#
#                                                  Name Age Group  PassengerId  \
# 248                     Beckwith, Mr. Richard Leonard         2          249
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         2          872
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 248       1    0       1.0  11751    D           3        0  Beckwith    Mr
# 871       1    1       1.0  11751    D           3        0  Beckwith   Mrs
#
#      IsChild
# 248        0
# 871        0
# 11752      Age Cabin  Embarked     Fare                          Name Age Group  \
# 136  19.0   D47       2.0  26.2833  Newsom, Miss. Helen Monypeny         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 136          137       1    1       1.0  11752    D           3        0
#
#     Surname Title  IsChild
# 136  Newsom  Miss        0
# 11753      Age Cabin  Embarked     Fare  \
# 621  42.0   D19       2.0  52.5542
# 935  45.0   D19       2.0  52.5542
#
#                                                  Name Age Group  PassengerId  \
# 621                      Kimball, Mr. Edwin Nelson Jr         2          622
# 935  Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)         2          936
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 621       1    0       1.0  11753    D           2        0  Kimball    Mr
# 935       1    1       NaN  11753    D           2        0  Kimball   Mrs
#
#      IsChild
# 621        0
# 935        0
# 11755      Age Cabin  Embarked  Fare  \
# 556  48.0   A16       0.0  39.6
#
#                                                   Name Age Group  PassengerId  \
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...         2          557
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone      Surname  \
# 556       1    1       1.0  11755    A           2        0  Duff Gordon
#
#     Title  IsChild
# 556  Lady        0
# 11765       Age Cabin  Embarked     Fare  \
# 370   25.0   E50       0.0  55.4417
# 1255  25.0   E50       0.0  55.4417
#
#                                               Name Age Group  PassengerId  \
# 370                    Harder, Mr. George Achilles         2          371
# 1255  Harder, Mrs. George Achilles (Dorothy Annan)         2         1256
#
#       Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone Surname Title  \
# 370        1    0       1.0  11765    E           2        0  Harder    Mr
# 1255       1    1       NaN  11765    E           2        0  Harder   Mrs
#
#       IsChild
# 370         0
# 1255        0
# 11767       Age Cabin  Embarked     Fare  \
# 310   24.0   C54       0.0  83.1583
# 879   56.0   C50       0.0  83.1583
# 1041  23.0   C54       0.0  83.1583
#
#                                                Name Age Group  PassengerId  \
# 310                  Hays, Miss. Margaret Bechstein         2          311
# 879   Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         2          880
# 1041          Earnshaw, Mrs. Boulton (Olive Potter)         2         1042
#
#       Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 310        1    1       1.0  11767    C           1        1      Hays  Miss
# 879        1    1       1.0  11767    C           2        0    Potter   Mrs
# 1041       1    1       NaN  11767    C           2        0  Earnshaw   Mrs
#
#       IsChild
# 310         0
# 879         0
# 1041        0
# 11769       Age Cabin  Embarked     Fare  \
# 571   53.0  C101       2.0  51.4792
# 1247  59.0  C101       2.0  51.4792
#
#                                                 Name Age Group  PassengerId  \
# 571    Appleton, Mrs. Edward Dale (Charlotte Lamson)         2          572
# 1247  Brown, Mrs. John Murray (Caroline Lane Lamson)         2         1248
#
#       Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 571        1    1       1.0  11769    C           3        0  Appleton   Mrs
# 1247       1    1       NaN  11769    C           3        0     Brown   Mrs
#
#       IsChild
# 571         0
# 1247        0
# 11770      Age Cabin  Embarked  Fare  \
# 968  55.0  C101       2.0  25.7
#
#                                                   Name Age Group  PassengerId  \
# 968  Cornell, Mrs. Robert Clifford (Malvina Helen L...         2          969
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  Surname Title  \
# 968       1    1       NaN  11770    C           3        0  Cornell   Mrs
#
#      IsChild
# 968        0
# 11771      Age Cabin  Embarked  Fare                     Name Age Group  \
# 487  58.0   B37       0.0  29.7  Kent, Mr. Edward Austin         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 487          488       1    0       0.0  11771    B           1        1
#
#     Surname Title  IsChild
# 487    Kent    Mr        0
# 11774      Age Cabin  Embarked  Fare                  Name Age Group  PassengerId  \
# 839  42.0   C47       0.0  29.7  Marechal, Mr. Pierre         2          840
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 839       1    0       1.0  11774    C           1        1  Marechal    Mr
#
#      IsChild
# 839        0
# 11778       Age Cabin  Embarked     Fare  \
# 991   43.0  C116       0.0  55.4417
# 1068  54.0  C116       0.0  55.4417
#
#                                                    Name Age Group  \
# 991   Stengel, Mrs. Charles Emil Henry (Annie May Mo...         2
# 1068                    Stengel, Mr. Charles Emil Henry         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 991           992       1    1       NaN  11778    C           2        0
# 1068         1069       1    0       NaN  11778    C           2        0
#
#       Surname Title  IsChild
# 991   Stengel   Mrs        0
# 1068  Stengel    Mr        0
# 11813      Age Cabin  Embarked     Fare  \
# 218  32.0   D15       0.0  76.2917
# 939  60.0   D15       0.0  76.2917
#
#                                                 Name Age Group  PassengerId  \
# 218                            Bazzani, Miss. Albina         2          219
# 939  Bucknell, Mrs. William Robert (Emma Eliza Ward)         2          940
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone   Surname Title  \
# 218       1    1       1.0  11813    D           1        1   Bazzani  Miss
# 939       1    1       NaN  11813    D           1        1  Bucknell   Mrs
#
#      IsChild
# 218        0
# 939        0
# 11967      Age Cabin  Embarked     Fare                                     Name  \
# 291  19.0   B49       0.0  91.0792  Bishop, Mrs. Dickinson H (Helen Walton)
# 484  25.0   B49       0.0  91.0792                  Bishop, Mr. Dickinson H
#
#     Age Group  PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  \
# 291         2          292       1    1       1.0  11967    B           2
# 484         2          485       1    0       1.0  11967    B           2
#
#      IsAlone Surname Title  IsChild
# 291        0  Bishop   Mrs        0
# 484        0  Bishop    Mr        0
# 1222       Age Cabin  Embarked    Fare                 Name Age Group  \
# 1248  25.0   NaN       2.0  7.8792  Lockyer, Mr. Edward         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 1248         1249       3    0       NaN   1222    Z           1        1
#
#       Surname Title  IsChild
# 1248  Lockyer    Mr        0
# 12233      Age Cabin  Embarked  Fare                          Name Age Group  \
# 722  34.0   NaN       2.0  13.0  Gillespie, Mr. William Henry         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 722          723       2    0       0.0  12233    Z           1        1
#
#        Surname Title  IsChild
# 722  Gillespie    Mr        0
# 12460      Age Cabin  Embarked  Fare                      Name Age Group  \
# 790  25.0   NaN       1.0  7.75  Keane, Mr. Andrew "Andy"         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 790          791       3    0       0.0  12460    Z           1        1
#
#     Surname Title  IsChild
# 790   Keane    Mr        0
# 12749       Age Cabin  Embarked  Fare  \
# 520   30.0   B73       2.0  93.5
# 820   52.0   B69       2.0  93.5
# 1199  55.0   B69       2.0  93.5
# 1281  23.0   B24       2.0  93.5
#
#                                                    Name Age Group  \
# 520                               Perreault, Miss. Anne         2
# 820   Hays, Mrs. Charles Melville (Clara Jennings Gr...         2
# 1199                         Hays, Mr. Charles Melville         2
# 1281                         Payne, Mr. Vivian Ponsonby         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 520           521       1    1       1.0  12749    B           1        1
# 820           821       1    1       1.0  12749    B           3        0
# 1199         1200       1    0       NaN  12749    B           3        0
# 1281         1282       1    0       NaN  12749    B           1        1
#
#         Surname Title  IsChild
# 520   Perreault  Miss        0
# 820        Hays   Mrs        0
# 1199       Hays    Mr        0
# 1281      Payne    Mr        0
# 13049      Age Cabin  Embarked    Fare                 Name Age Group  PassengerId  \
# 583  36.0   A10       0.0  40.125  Ross, Mr. John Hugo         2          584
#
#      Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone Surname Title  \
# 583       1    0       0.0  13049    A           1        1    Ross    Mr
#
#      IsChild
# 583        0
# 13050       Age Cabin  Embarked     Fare                          Name Age Group  \
# 1009  36.0    C6       0.0  75.2417          Beattie, Mr. Thomson         2
# 1161  46.0    C6       0.0  75.2417  McCaffry, Mr. Thomas Francis         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 1009         1010       1    0       NaN  13050    C           1        1
# 1161         1162       1    0       NaN  13050    C           1        1
#
#        Surname Title  IsChild
# 1009   Beattie    Mr        0
# 1161  McCaffry    Mr        0
# 13213      Age Cabin  Embarked  Fare                                 Name  \
# 647  56.0   A26       0.0  35.5  Simonius-Blumer, Col. Oberst Alfons
#
#     Age Group  PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  \
# 647         2          648       1    0       1.0  13213    A           1
#
#      IsAlone          Surname Title  IsChild
# 647        1  Simonius-Blumer   Col        0
# 13214      Age Cabin  Embarked  Fare                       Name Age Group  \
# 632  32.0   B50       0.0  30.5  Stahelin-Maeglin, Dr. Max         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 632          633       1    0       1.0  13214    B           1        1
#
#               Surname Title  IsChild
# 632  Stahelin-Maeglin    Dr        0
# 13236       Age Cabin  Embarked   Fare                             Name Age Group  \
# 925   30.0   C78       0.0  57.75         Mock, Mr. Philipp Edmund         2
# 1013  35.0   C28       0.0  57.75  Schabert, Mrs. Paul (Emma Mock)         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 925           926       1    0       NaN  13236    C           2        0
# 1013         1014       1    1       NaN  13236    C           2        0
#
#        Surname Title  IsChild
# 925       Mock    Mr        0
# 1013  Schabert   Mrs        0
# 13502      Age Cabin  Embarked     Fare                                  Name  \
# 275  63.0    D7       2.0  77.9583     Andrews, Miss. Kornelia Theodosia
# 627  21.0    D9       2.0  77.9583         Longley, Miss. Gretchen Fiske
# 765  51.0   D11       2.0  77.9583  Hogeboom, Mrs. John C (Anna Andrews)
#
#     Age Group  PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  \
# 275         2          276       1    1       1.0  13502    D           2
# 627         2          628       1    1       1.0  13502    D           1
# 765         2          766       1    1       1.0  13502    D           2
#
#      IsAlone   Surname Title  IsChild
# 275        0   Andrews  Miss        0
# 627        1   Longley  Miss        0
# 765        0  Hogeboom   Mrs        0
# 13507      Age Cabin  Embarked  Fare                                       Name  \
# 434  50.0   E44       2.0  55.9                  Silvey, Mr. William Baird
# 577  39.0   E44       2.0  55.9  Silvey, Mrs. William Baird (Alice Munger)
#
#     Age Group  PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  \
# 434         2          435       1    0       0.0  13507    E           2
# 577         2          578       1    1       1.0  13507    E           2
#
#      IsAlone Surname Title  IsChild
# 434        0  Silvey    Mr        0
# 577        0  Silvey   Mrs        0
# 13508       Age Cabin  Embarked      Fare  \
# 1143  27.0   C89       0.0  136.7792
# 1163  26.0   C89       0.0  136.7792
#
#                                                Name Age Group  PassengerId  \
# 1143                       Clark, Mr. Walter Miller         2         1144
# 1163  Clark, Mrs. Walter Miller (Virginia McDowell)         2         1164
#
#       Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone Surname Title  \
# 1143       1    0       NaN  13508    C           2        0   Clark    Mr
# 1163       1    1       NaN  13508    C           2        0   Clark   Mrs
#
#       IsChild
# 1143        0
# 1163        0
# 13509      Age Cabin  Embarked   Fare                       Name Age Group  \
# 456  65.0   E38       2.0  26.55  Millet, Mr. Francis Davis         2
#
#      PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# 456          457       1    0       0.0  13509    E           1        1
#
#     Surname Title  IsChild
# 456  Millet    Mr        0
# 13567       Age Cabin  Embarked  Fare  \
# 587   60.0   B41       0.0  79.2
# 1288  48.0   B41       0.0  79.2
#
#                                                    Name Age Group  \
# 587                    Frolicher-Stehli, Mr. Maxmillian         2
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...         2
#
#       PassengerId  Pclass  Sex  Survived Ticket Deck  FamilySize  IsAlone  \
# ...
#
#      Pclass  Sex  Survived             Ticket Deck  FamilySize  IsAlone  \
# 590       3    0       0.0  STON/O 2. 3101273    Z           1        1
#
#        Surname Title  IsChild
# 590  Rintamaki    Mr        0
# STON/O 2. 3101274      Age Cabin  Embarked   Fare                        Name Age Group  \
# 433  17.0   NaN       2.0  7.125  Kallio, Mr. Nikolai Erland         1
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 433          434       3    0       0.0  STON/O 2. 3101274    Z           1
#
#      IsAlone Surname Title  IsChild
# 433        1  Kallio    Mr        0
# STON/O 2. 3101275      Age Cabin  Embarked   Fare                           Name Age Group  \
# 243  22.0   NaN       2.0  7.125  Maenpaa, Mr. Matti Alexanteri         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 243          244       3    0       0.0  STON/O 2. 3101275    Z           1
#
#      IsAlone  Surname Title  IsChild
# 243        1  Maenpaa    Mr        0
# STON/O 2. 3101280      Age Cabin  Embarked   Fare                       Name Age Group  \
# 173  21.0   NaN       2.0  7.925  Sivola, Mr. Antti Wilhelm         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 173          174       3    0       0.0  STON/O 2. 3101280    Z           1
#
#      IsAlone Surname Title  IsChild
# 173        1  Sivola    Mr        0
# STON/O 2. 3101285      Age Cabin  Embarked   Fare                         Name Age Group  \
# 664  20.0   NaN       2.0  7.925  Lindqvist, Mr. Eino William         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 664          665       3    0       1.0  STON/O 2. 3101285    Z           2
#
#      IsAlone    Surname Title  IsChild
# 664        0  Lindqvist    Mr        0
# STON/O 2. 3101286      Age Cabin  Embarked   Fare                 Name Age Group  PassengerId  \
# 579  32.0   NaN       2.0  7.925  Jussila, Mr. Eiriik         2          580
#
#      Pclass  Sex  Survived             Ticket Deck  FamilySize  IsAlone  \
# 579       3    0       1.0  STON/O 2. 3101286    Z           1        1
#
#      Surname Title  IsChild
# 579  Jussila    Mr        0
# STON/O 2. 3101288      Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 744  31.0   NaN       2.0  7.925  Stranden, Mr. Juho         2          745
#
#      Pclass  Sex  Survived             Ticket Deck  FamilySize  IsAlone  \
# 744       3    0       1.0  STON/O 2. 3101288    Z           1        1
#
#       Surname Title  IsChild
# 744  Stranden    Mr        0
# STON/O 2. 3101289      Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 400  39.0   NaN       2.0  7.925  Niskanen, Mr. Juha         2          401
#
#      Pclass  Sex  Survived             Ticket Deck  FamilySize  IsAlone  \
# 400       3    0       1.0  STON/O 2. 3101289    Z           1        1
#
#       Surname Title  IsChild
# 400  Niskanen    Mr        0
# STON/O 2. 3101291      Age Cabin  Embarked   Fare                             Name Age Group  \
# 936  25.0   NaN       2.0  7.925  Peltomaki, Mr. Nikolai Johannes         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 936          937       3    0       NaN  STON/O 2. 3101291    Z           1
#
#      IsAlone    Surname Title  IsChild
# 936        1  Peltomaki    Mr        0
# STON/O 2. 3101292      Age Cabin  Embarked   Fare                        Name Age Group  \
# 636  32.0   NaN       2.0  7.925  Leinonen, Mr. Antti Gustaf         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 636          637       3    0       0.0  STON/O 2. 3101292    Z           1
#
#      IsAlone   Surname Title  IsChild
# 636        1  Leinonen    Mr        0
# STON/O 2. 3101293      Age Cabin  Embarked   Fare                Name Age Group  PassengerId  \
# 382  32.0   NaN       2.0  7.925  Tikkanen, Mr. Juho         2          383
#
#      Pclass  Sex  Survived             Ticket Deck  FamilySize  IsAlone  \
# 382       3    0       0.0  STON/O 2. 3101293    Z           1        1
#
#       Surname Title  IsChild
# 382  Tikkanen    Mr        0
# STON/O 2. 3101294      Age Cabin  Embarked   Fare                   Name Age Group  \
# 115  21.0   NaN       2.0  7.925  Pekoniemi, Mr. Edvard         2
#
#      PassengerId  Pclass  Sex  Survived             Ticket Deck  FamilySize  \
# 115          116       3    0       0.0  STON/O 2. 3101294    Z           1
#
#      IsAlone    Surname Title  IsChild
# 115        1  Pekoniemi    Mr        0
# STON/O2. 3101270      Age Cabin  Embarked   Fare                          Name Age Group  \
# 909  27.0   NaN       2.0  7.925  Ilmakangas, Miss. Ida Livija         2
#
#      PassengerId  Pclass  Sex  Survived            Ticket Deck  FamilySize  \
# 909          910       3    1       NaN  STON/O2. 3101270    Z           2
#
#      IsAlone     Surname Title  IsChild
# 909        0  Ilmakangas  Miss        0
# STON/O2. 3101271      Age Cabin  Embarked   Fare                           Name Age Group  \
# 729  25.0   NaN       2.0  7.925  Ilmakangas, Miss. Pieta Sofia         2
#
#      PassengerId  Pclass  Sex  Survived            Ticket Deck  FamilySize  \
# 729          730       3    1       0.0  STON/O2. 3101271    Z           2
#
#      IsAlone     Surname Title  IsChild
# 729        0  Ilmakangas  Miss        0
# STON/O2. 3101279      Age Cabin  Embarked   Fare  \
# 142  24.0   NaN       2.0  15.85
# 403  28.0   NaN       2.0  15.85
#
#                                                   Name Age Group  PassengerId  \
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...         2          143
# 403                     Hakkarainen, Mr. Pekka Pietari         2          404
#
#      Pclass  Sex  Survived            Ticket Deck  FamilySize  IsAlone  \
# 142       3    1       1.0  STON/O2. 3101279    Z           2        0
# 403       3    0       0.0  STON/O2. 3101279    Z           2        0
#
#          Surname Title  IsChild
# 142  Hakkarainen   Mrs        0
# 403  Hakkarainen    Mr        0
# STON/O2. 3101282    Age Cabin  Embarked   Fare                    Name Age Group  PassengerId  \
# 2  26.0   NaN       2.0  7.925  Heikkinen, Miss. Laina         2            3
#
#    Pclass  Sex  Survived            Ticket Deck  FamilySize  IsAlone  \
# 2       3    1       1.0  STON/O2. 3101282    Z           1        1
#
#      Surname Title  IsChild
# 2  Heikkinen  Miss        0
# STON/O2. 3101283      Age Cabin  Embarked   Fare                    Name Age Group  \
# 216  27.0   NaN       2.0  7.925  Honkanen, Miss. Eliina         2
#
#      PassengerId  Pclass  Sex  Survived            Ticket Deck  FamilySize  \
# 216          217       3    1       1.0  STON/O2. 3101283    Z           1
#
#      IsAlone   Surname Title  IsChild
# 216        1  Honkanen  Miss        0
# STON/O2. 3101290      Age Cabin  Embarked   Fare                          Name Age Group  \
# 816  23.0   NaN       2.0  7.925  Heininen, Miss. Wendla Maria         2
#
#      PassengerId  Pclass  Sex  Survived            Ticket Deck  FamilySize  \
# 816          817       3    1       0.0  STON/O2. 3101290    Z           1
#
#      IsAlone   Surname Title  IsChild
# 816        1  Heininen  Miss        0
# STON/OQ. 369943       Age Cabin  Embarked  Fare                     Name Age Group  \
# 1021  32.0   NaN       2.0  8.05  Spinner, Mr. Henry John         2
#
#       PassengerId  Pclass  Sex  Survived           Ticket Deck  FamilySize  \
# 1021         1022       3    0       NaN  STON/OQ. 369943    Z           1
#
#       IsAlone  Surname Title  IsChild
# 1021        1  Spinner    Mr        0
# SW/PP 751      Age Cabin  Embarked  Fare                       Name Age Group  \
# 226  19.0   NaN       2.0  10.5  Mellors, Mr. William John         2
#
#      PassengerId  Pclass  Sex  Survived     Ticket Deck  FamilySize  IsAlone  \
# 226          227       2    0       1.0  SW/PP 751    Z           1        1
#
#      Surname Title  IsChild
# 226  Mellors    Mr        0
# W./C. 14258      Age Cabin  Embarked  Fare                  Name Age Group  PassengerId  \
# 526  50.0   NaN       2.0  10.5  Ridsdale, Miss. Lucy         2          527
#
#      Pclass  Sex  Survived       Ticket Deck  FamilySize  IsAlone   Surname  \
# 526       2    1       1.0  W./C. 14258    Z           1        1  Ridsdale
#
#     Title  IsChild
# 526  Miss        0
# W./C. 14260       Age Cabin  Embarked  Fare                       Name Age Group  \
# 1170  22.0   NaN       2.0  10.5  Oxenham, Mr. Percy Thomas         2
#
#       PassengerId  Pclass  Sex  Survived       Ticket Deck  FamilySize  \
# 1170         1171       2    0       NaN  W./C. 14260    Z           1
#
#       IsAlone  Surname Title  IsChild
# 1170        1  Oxenham    Mr        0
# W./C. 14263      Age Cabin  Embarked  Fare                             Name Age Group  \
# 242  29.0   NaN       2.0  10.5  Coleridge, Mr. Reginald Charles         2
#
#      PassengerId  Pclass  Sex  Survived       Ticket Deck  FamilySize  \
# 242          243       2    0       0.0  W./C. 14263    Z           1
#
#      IsAlone    Surname Title  IsChild
# 242        1  Coleridge    Mr        0
# W./C. 14266       Age Cabin  Embarked  Fare                        Name Age Group  \
# 1113  22.0   F33       2.0  10.5  Cook, Mrs. (Selena Rogers)         2
#
#       PassengerId  Pclass  Sex  Survived       Ticket Deck  FamilySize  \
# 1113         1114       2    1       NaN  W./C. 14266    F           1
#
#       IsAlone Surname Title  IsChild
# 1113        1    Cook   Mrs        0
# W./C. 6607       Age Cabin  Embarked   Fare  \
# 783   25.0   NaN       2.0  23.45
# 888   22.0   NaN       2.0  23.45
# 924   22.0   NaN       2.0  23.45
# 1135  25.0   NaN       2.0  23.45
#
#                                                    Name Age Group  \
# 783                              Johnston, Mr. Andrew G         2
# 888            Johnston, Miss. Catherine Helen "Carrie"         2
# 924   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"         2
# 1135          Johnston, Master. William Arthur Willie""         2
#
#       PassengerId  Pclass  Sex  Survived      Ticket Deck  FamilySize  \
# 783           784       3    0       0.0  W./C. 6607    Z           4
# 888           889       3    1       0.0  W./C. 6607    Z           4
# 924           925       3    1       NaN  W./C. 6607    Z           4
# 1135         1136       3    0       NaN  W./C. 6607    Z           4
#
#       IsAlone   Surname   Title  IsChild
# 783         0  Johnston      Mr        0
# 888         0  Johnston    Miss        0
# 924         0  Johnston     Mrs        0
# 1135        0  Johnston  Master        0
# W./C. 6608       Age Cabin  Embarked    Fare                                     Name  \
# 86    16.0   NaN       2.0  34.375                   Ford, Mr. William Neal
# 147    9.0   NaN       2.0  34.375         Ford, Miss. Robina Maggie "Ruby"
# 436   21.0   NaN       2.0  34.375     Ford, Miss. Doolina Margaret "Daisy"
# 736   48.0   NaN       2.0  34.375  Ford, Mrs. Edward (Margaret Ann Watson)
# 1058  18.0   NaN       2.0  34.375                  Ford, Mr. Edward Watson
#
#      Age Group  PassengerId  Pclass  Sex  Survived      Ticket Deck  \
# 86           1           87       3    0       0.0  W./C. 6608    Z
# 147          1          148       3    1       0.0  W./C. 6608    Z
# 436          2          437       3    1       0.0  W./C. 6608    Z
# 736          2          737       3    1       0.0  W./C. 6608    Z
# 1058         2         1059       3    0       NaN  W./C. 6608    Z
#
#       FamilySize  IsAlone Surname Title  IsChild
# 86             5        0    Ford    Mr        0
# 147            5        0    Ford  Miss        1
# 436            5        0    Ford  Miss        0
# 736            5        0    Ford   Mrs        0
# 1058           5        0    Ford    Mr        0
# W./C. 6609      Age Cabin  Embarked  Fare                          Name Age Group  \
# 235  22.0   NaN       2.0  7.55  Harknett, Miss. Alice Phoebe         2
#
#      PassengerId  Pclass  Sex  Survived      Ticket Deck  FamilySize  IsAlone  \
# 235          236       3    1       0.0  W./C. 6609    Z           1        1
#
#       Surname Title  IsChild
# 235  Harknett  Miss        0
# W.E.P. 5734      Age Cabin  Embarked    Fare  \
# 92   46.0   E31       2.0  61.175
# 905  47.0   E31       2.0  61.175
#
#                                                   Name Age Group  PassengerId  \
# 92                         Chaffee, Mr. Herbert Fuller         2           93
# 905  Chaffee, Mrs. Herbert Fuller (Carrie Constance...         2          906
#
#      Pclass  Sex  Survived       Ticket Deck  FamilySize  IsAlone  Surname  \
# 92        1    0       0.0  W.E.P. 5734    E           2        0  Chaffee
# 905       1    1       NaN  W.E.P. 5734    E           2        0  Chaffee
#
#     Title  IsChild
# 92     Mr        0
# 905   Mrs        0
# W/C 14208      Age Cabin  Embarked  Fare                Name Age Group  PassengerId  \
# 219  30.0   NaN       2.0  10.5  Harris, Mr. Walter         2          220
#
#      Pclass  Sex  Survived     Ticket Deck  FamilySize  IsAlone Surname Title  \
# 219       2    0       0.0  W/C 14208    Z           1        1  Harris    Mr
#
#      IsChild
# 219        0
# WE/P 5735      Age Cabin  Embarked  Fare                          Name Age Group  \
# 540  36.0   B22       2.0  71.0       Crosby, Miss. Harriet R         2
# 745  70.0   B22       2.0  71.0  Crosby, Capt. Edward Gifford         3
#
#      PassengerId  Pclass  Sex  Survived     Ticket Deck  FamilySize  IsAlone  \
# 540          541       1    1       1.0  WE/P 5735    B           3        0
# 745          746       1    0       0.0  WE/P 5735    B           3        0
#
#     Surname Title  IsChild
# 540  Crosby  Miss        0
# 745  Crosby  Capt        0
# Printing Sample Data Entries to Verify Grouping:
#
#
#      Surname  FamilySize  Ticket  GroupID  GroupType  GroupSize
# 257  Cherry           1  110152        1  NonFamily          3
# 504  Maioni           1  110152        1  NonFamily          3
# 759  Rothes           1  110152        1  NonFamily          3
#
#       Surname  FamilySize  Ticket  GroupID GroupType  GroupSize
# 262  Taussig           3  110413        2    Family          3
# 558  Taussig           3  110413        2    Family          3
# 585  Taussig           3  110413        2    Family          3
#
#        Surname  FamilySize  Ticket  GroupID  GroupType  GroupSize
# 110    Porter           1  110465        3  NonFamily          2
# 475  Clifford           1  110465        3  NonFamily          2
#
#        Surname  FamilySize  Ticket  GroupID GroupType  GroupSize
# 1226  Maguire           1  110469        4   IsAlone          1
#       GroupID  GroupSize  Survived  GroupNumSurvived  GroupNumPerished
# 504         1          3       1.0                 3                 0
# 257         1          3       1.0                 3                 0
# 759         1          3       1.0                 3                 0
# 585         2          3       1.0                 2                 1
# 262         2          3       0.0                 2                 1
# 558         2          3       1.0                 2                 1
# 110         3          2       0.0                 0                 2
# 475         3          2       0.0                 0                 2
# 1226        4          1       NaN                 0                 0
# 1049        5          1       NaN                 0                 0
# 430         6          1       1.0                 1                 0
# 366         7          2       1.0                 1                 0
# 1127        7          2       NaN                 1                 0
# 1082        8          1       NaN                 0                 0
# 170         9          1       0.0                 0                 1

# %% [markdown]
# 6 Checking For Inconsistencies
# ===

# %%
# Check for cases where FamilySize = 1 but GroupType = Family
data_reduced = dataset[dataset['FamilySize'] == 1]
data_reduced = data_reduced[data_reduced['GroupType'] == 'Family']

# nri = 'NumRelatives inconsistency'
nri_passenger_ids = data_reduced['PassengerId'].values
nri_unique_surnames = set(data_reduced['Surname'].values)

# How many occurrences?
print('Number of nri Passengers: ', len(nri_passenger_ids))
print('Number of Unique nri Surnames: ',len(nri_unique_surnames))

# We will find that there are only 7 occurences, so let's go ahead and view them here:
data_reduced = data_reduced.sort_values('Name')
data_reduced[['Name', 'Ticket', 'Fare','Pclass', 'Parch', 
              'SibSp', 'GroupID', 'GroupSize','GroupType']].head(int(len(nri_passenger_ids)))

# %% [markdown]
# With the exception of Mrs. John James Ware, we see that each of these passengers is paired with another having the same surname; we can presume that these are 2nd-degree relations (such as cousins), hence why each still has FamilySize=1 (which refers only to immediate family).

# %%
#Check for cases where FamilySize > 1 but GroupType = NonFamily
data_reduced = dataset[dataset['FamilySize'] > 1]
data_reduced = data_reduced[data_reduced['GroupType'] == 'NonFamily']

# ngwr = 'not grouped with relatives'
ngwr_passenger_ids = data_reduced['PassengerId'].values
ngwr_unique_surnames = set(data_reduced['Surname'].values)

# How many occurences?
print('Number of ngwr Passengers: ', len(ngwr_passenger_ids))
print('Number of Unique ngwr Surnames: ',len(ngwr_unique_surnames))

feature_list = ['PassengerId', 'Name', 'Ticket', 'Fare','Pclass', 'Parch', 
                'SibSp', 'GroupID', 'GroupSize','GroupType']
data_reduced[feature_list].sort_values('GroupID').head(int(len(ngwr_unique_surnames)))

# %% [markdown]
# If we look at matching group IDs, then in some cases these inconsistencies may be due to passenger substitutions. However, we need to better understand the significance of the names in parenthesis.
#
# Consider GroupID=628: we have "Miss Elizabith Eustis" and "Mrs. Walter Sephenson (Martha Eustis)". A quick check of geneology databases online reports that there was indeed a miss Mrs. Walter Bertram Stephenson that boarded the Titanic; in this case, Martha Eustis is her maiden name, while Mrs. Walter B. Stephenson gives her title in terms of her husband's name (an old-fashioned practice). Another example is for GroupID=77, where we have "Brown, Mrs. John Murray (Caroline Lane Lamson)" and "Appleton, Mrs. Edward Dale (Charlotte Lamson)", another case of two related passengers whose names are given in terms of those of their husbands.
#
# Since this hunt for inconsistencies turned up only 17 entries, we can manually correct the Group Type in cases (such as these two examples) where it is obvious the passengers are indeed family.

# %%
# manually correcting some mislabeled group types
# note: if group size is greater than the number of listed names above, we assign to Mixed
passenger_ids_toFamily = [167, 357, 572, 1248, 926, 1014, 260, 881, 592, 497]
passenger_ids_toMixed = [880, 1042, 276, 766]

dataset['GroupType'][dataset['PassengerId'].isin(passenger_ids_toFamily)] = 'Family'
dataset['GroupType'][dataset['PassengerId'].isin(passenger_ids_toMixed)] = 'Mixed'

## for verification:
# feature_list = ['PassengerId', 'Name', 'GroupID', 'GroupSize','GroupType']
# dataset[feature_list][dataset['PassengerId'].isin(
#         passenger_ids_toFamily)].sort_values('GroupID').head(len(passenger_ids_toFamily))

# %% [markdown]
# 20 Correlation without NaNs
# ---

# %%
jp1 = sns.jointplot(x="Pclass", y="Fare", kind='reg', data=df_data_1)
r, p = stats.pearsonr(df_data_1["Pclass"], df_data_1["Fare"])
phantom, = jp1.ax_joint.plot([], [], linestyle="", alpha=0)
jp1.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %%
t0 = time()
X_train = 
n_components = 4
pca = PCA(n_components=n_components, whiten=True).fit(X_train)
print("done in %0.3fs" % (time() - t0))

eigenfaces = pca.components_.reshape((n_components, h, w))

# %% [markdown]
# 4.5 Cabin
# ---

# %% [markdown]
# ![Cruiser4.PNG](attachment:Cruiser4.PNG)

# %% [markdown]
# **<span style='color:#F1C40F'>Cabin</span>** feature is little bit tricky and it needs further exploration. The large portion of the Cabin feature is missing and the feature itself **<span style='color:#F1C40F'>can't be ignored completely because some the cabins might have higher survival rates</span>**. It turns out to be the first letter of the Cabin values are the decks in which the cabins are located. Those decks were mainly separated for one passenger class, but some of them were used by multiple passenger classes.
# ![alt text](https://vignette.wikia.nocookie.net/titanic/images/f/f9/Titanic_side_plan.png/revision/latest?cb=20180322183733)
# * On the Boat Deck there were **6** rooms labeled as **T, U, W, X, Y, Z** but only the **T** cabin is present in the dataset
# * **A**, **B** decks were only for 1st class passengers and 2st class passengers (smoking rooms)
# * **C** first class for the majority and a minority of crew, second class and thrid class passengers
# * **D** and **E** decks were for all classes
# * **F** and **G** decks were for both 2nd and 3rd class passengers

# %%
# Creating Deck column from the first letter of the Cabin column (M stands for Missing)
df_data_1['Deck'] = df_data_1['Cabin'].apply(lambda s: s[0] if pd.notnull(s) else 'Z')
df_data_1.head(10)
# Out:
#     Age Cabin  Embarked     Fare  \
# 0  22.0   NaN       2.0   7.2500
# 1  38.0   C85       0.0  71.2833
# 2  26.0   NaN       2.0   7.9250
# 3  35.0  C123       2.0  53.1000
# 4  35.0   NaN       2.0   8.0500
# 5  25.0   NaN       1.0   8.4583
# 6  54.0   E46       2.0  51.8625
# 7   2.0   NaN       2.0  21.0750
# 8  27.0   NaN       2.0  11.1333
# 9  14.0   NaN       0.0  30.0708
#
#                                                 Name Age Group  Parch  \
# 0                            Braund, Mr. Owen Harris         2      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         2      0
# 2                             Heikkinen, Miss. Laina         2      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         2      0
# 4                           Allen, Mr. William Henry         2      0
# 5                                   Moran, Mr. James         2      0
# 6                            McCarthy, Mr. Timothy J         2      0
# 7                     Palsson, Master. Gosta Leonard         0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         2      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1      0
#
#    PassengerId  Pclass  Sex  SibSp  Survived            Ticket Deck
# 0            1       3    0      1       0.0         A/5 21171    Z
# 1            2       1    1      1       1.0          PC 17599    C
# 2            3       3    1      0       1.0  STON/O2. 3101282    Z
# 3            4       1    1      1       1.0            113803    C
# 4            5       3    0      0       0.0            373450    Z
# 5            6       3    0      0       0.0            330877    Z
# 6            7       1    0      0       0.0             17463    E
# 7            8       3    0      3       0.0            349909    Z
# 8            9       3    1      0       1.0            347742    Z
# 9           10       2    1      1       1.0            237736    Z
